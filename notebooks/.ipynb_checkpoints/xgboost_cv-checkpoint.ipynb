# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import os
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
import matplotlib.pyplot as plt
from tqdm import tqdm
import xgboost as xgb

# %%
#get blocks
dataset_path = './dataset/'
items = os.listdir(dataset_path)
blocks =[item for item in items if os.path.isdir(os.path.join(dataset_path, item))]

df_blocks_list = []
        
for block in blocks:

    #get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/net_feat.csv", sep=';')

    #drop all nets with zero capacitence
    df = df[df['cap'] != 0]
    df = df[df['pin_cap'] != 0]

    #drop all Nan rows
    df = df.dropna()

    #drop net name clomun
    df = df.drop(columns=['net'], axis=1)

    #append df to common df
    df_blocks_list.append(df)

#create common df
df = pd.concat(df_blocks_list, ignore_index=True)

#transfer capacintece from pF to fF
df['cap'] = df['cap'] * 1000
df['pin_cap'] = df['pin_cap'] * 1000
df['wireload_fan_cap'] = df['wireload_fan_cap'] * 1000
df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] * 1000

#add block area feature
df['block_area'] = df['block_width'] * df['block_height']

#add area feature
df['gcell_area'] = (df['urx'] - df['llx']) * (df['ury'] - df['lly'])

#add aspect ration feat
df['gcell_ar'] = (df['urx'] - df['llx']) / (df['ury'] - df['lly'])

df['abs_x']= (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']
df['abs_y']= (((df['ury'] - df['lly']) / 2) + df['lly']) / df['block_height']

df['dist_to_right'] = ((df['block_width'] - ((df['urx'] - df['llx']) / 2) + df['llx'])) / df['block_width']
df['dist_to_left'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']

df['dist_to_top'] = (df['block_height'] - (((df['ury'] - df['lly']) / 2) + df['lly'])) / df['block_height']
df['dist_to_bottom'] =(( ((df['ury'] - df['lly']) / 2) + df['lly']))

#ration wire cap / pin cap
#df ['wire_to_pin_cap_ratio'] = df['cap'] / df['pin_cap'] 

#drop metal segs
df = df.drop(columns=['m2_segs', 'm3_segs', 'm4_segs', 'm5_segs', 'm6_segs', 'm7_segs'])

#drop all labels except cap
df = df.drop(columns=['length', 'vias', 'segs'])

# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
from sklearn.preprocessing import StandardScaler

# get blocks
dataset_path = './dataset/'
items = os.listdir(dataset_path)
blocks = [item for item in items if os.path.isdir(os.path.join(dataset_path, item))]

df_blocks_list = []
block_names = []

for block in blocks:
    # get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/net_feat.csv", sep=';')

    # drop all nets with zero capacitence
    df = df[df['cap'] != 0]
    df = df[df['pin_cap'] != 0]

    # drop all Nan rows
    df = df.dropna()

    # drop net name column
    df = df.drop(columns=['net'], axis=1)
    
    # Add block identifier
    df['block_id'] = block
    
    # append df to common df
    df_blocks_list.append(df)
    block_names.append(block)

# create common df
df = pd.concat(df_blocks_list, ignore_index=True)

# transfer capacintece from pF to fF
df['cap'] = df['cap'] * 1000
df['pin_cap'] = df['pin_cap'] * 1000
df['wireload_fan_cap'] = df['wireload_fan_cap'] * 1000
df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] * 1000

# add block area feature
df['block_area'] = df['block_width'] * df['block_height']

# add area feature
df['gcell_area'] = (df['urx'] - df['llx']) * (df['ury'] - df['lly'])

# add aspect ration feat
df['gcell_ar'] = (df['urx'] - df['llx']) / (df['ury'] - df['lly'])

df['abs_x'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']
df['abs_y'] = (((df['ury'] - df['lly']) / 2) + df['lly']) / df['block_height']

df['dist_to_right'] = ((df['block_width'] - ((df['urx'] - df['llx']) / 2) + df['llx'])) / df['block_width']
df['dist_to_left'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']

df['dist_to_top'] = (df['block_height'] - (((df['ury'] - df['lly']) / 2) + df['lly'])) / df['block_height']
df['dist_to_bottom'] = ((((df['ury'] - df['lly']) / 2) + df['lly']))

# ration wire cap / pin cap
# df ['wire_to_pin_cap_ratio'] = df['cap'] / df['pin_cap'] 

# drop metal segs
df = df.drop(columns=['m2_segs', 'm3_segs', 'm4_segs', 'm5_segs', 'm6_segs', 'm7_segs'])

# drop all labels except cap
df = df.drop(columns=['length', 'vias', 'segs'])

# Определяем фичи и таргет
#features = [col for col in df.columns if col not in ['cap', 'block_id']]
features = ['fanout', 'fanout_area', 'hpwl', 'hpwl_min', 'hpwl_max', 'hpwl_mean', 'hpwl_stddev', 'pin_cap', 'wireload_fan_cap', 'wireload_hpwl_cap', 'gcell_area']
X = df[features]
y = df['cap']
groups = df['block_id']

# Инициализируем GroupKFold
n_splits = min(7, len(blocks))  # минимум 5 фолдов или количество блоков, если их меньше
gkf = GroupKFold(n_splits=n_splits)

# Метрики для хранения результатов
mse_scores = []
mae_scores = []
r2_scores = []
feature_importances = []

print(f"Всего блоков: {len(blocks)}")
print(f"Количество фолдов: {n_splits}")
print(f"Фичи: {features}")

# Кросс-валидация по блокам
for fold, (train_idx, test_idx) in enumerate(gkf.split(X, y, groups=groups)):
    print(f"\n--- Фолд {fold + 1} ---")
    
    # Разделяем данные
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    # Получаем названия блоков в train и test
    train_blocks = groups.iloc[train_idx].unique()
    test_blocks = groups.iloc[test_idx].unique()
    
    print(f"Тренировочные блоки: {train_blocks}")
    print(f"Тестовые блоки: {test_blocks}")
    print(f"Тренировочные samples: {len(X_train)}")
    print(f"Тестовые samples: {len(X_test)}")
    
    # Масштабирование фичей
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Обучаем XGBoost
    model = xgb.XGBRegressor(
        n_estimators=100,
        max_depth=20,
        learning_rate=0.1,
        random_state=42
    )
    
    model.fit(X_train_scaled, y_train)
    
    # Предсказания
    y_pred = model.predict(X_test_scaled)
    
    # Вычисляем метрики
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    mse_scores.append(mse)
    mae_scores.append(mae)
    r2_scores.append(r2)
    
    # Сохраняем важность фичей
    feature_importances.append(model.feature_importances_)
    
    print(f"MSE: {mse:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"R²: {r2:.4f}")

# Выводим итоговые результаты
print("\n" + "="*50)
print("ИТОГИ КРОСС-ВАЛИДАЦИИ")
print("="*50)
print(f"Среднее MSE: {np.mean(mse_scores):.4f} (±{np.std(mse_scores):.4f})")
print(f"Среднее MAE: {np.mean(mae_scores):.4f} (±{np.std(mae_scores):.4f})")
print(f"Среднее R²: {np.mean(r2_scores):.4f} (±{np.std(r2_scores):.4f})")

# Анализ важности фичей
avg_feature_importance = np.mean(feature_importances, axis=0)
feature_importance_df = pd.DataFrame({
    'feature': features,
    'importance': avg_feature_importance
}).sort_values('importance', ascending=False)

print("\nВажность фичей (средняя по фолдам):")
print(feature_importance_df)

# Визуализация важности фичей (опционально)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['feature'], feature_importance_df['importance'])
plt.xlabel('Важность')
plt.title('Средняя важность фичей по фолдам')
plt.tight_layout()
plt.show()

# Обучение финальной модели на всех данных (опционально)
print("\nОбучение финальной модели на всех данных...")
final_scaler = StandardScaler()
X_scaled = final_scaler.fit_transform(X)

final_model = xgb.XGBRegressor(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    random_state=42
)
final_model.fit(X_scaled, y)

print("Финальная модель обучена!")
# Out:
# Всего блоков: 35
# Количество фолдов: 7
# Фичи: ['fanout', 'fanout_area', 'hpwl', 'hpwl_min', 'hpwl_max', 'hpwl_mean', 'hpwl_stddev', 'pin_cap', 'wireload_fan_cap', 'wireload_hpwl_cap', 'gcell_area']
#
# --- Фолд 1 ---
# Тренировочные блоки: ['simple_spi_top' 'jpeg_encoder' 'FIR_filter' 'rs_encode' 'sasc_top'
#  'usb_phy' 'Top_PipelinedCipher' 'wb_conmax_top' 'ac97_top' 'RocketTile'
#  'psram_core' 'pci_bridge32' 'spi_top' 'vga_enh_top' 'risc16f84_clk2x'
#  'aes128_core' 'mrisc_top' 'aes_core' 'Sha3BlackBox' 'fpu' 'RsEncodeTop'
#  'sdram' 'dynamic_node_top_wrap' 'RsDecodeTop' 'picosoc' 'mips_core'
#  'pcm_slv_top' 'des3' 'mc_top' 'aes_cipher_top' 'wb_dma_top' 'plic_core'
#  'sha256' 'dft_top']
# Тестовые блоки: ['Network']
# Тренировочные samples: 349112
# Тестовые samples: 215786
# MSE: 12.8368
# MAE: 0.8900
# R²: 0.8988
#
# --- Фолд 2 ---
# Тренировочные блоки: ['simple_spi_top' 'jpeg_encoder' 'FIR_filter' 'rs_encode' 'sasc_top'
#  'usb_phy' 'Network' 'wb_conmax_top' 'ac97_top' 'RocketTile' 'psram_core'
#  'pci_bridge32' 'spi_top' 'vga_enh_top' 'risc16f84_clk2x' 'aes128_core'
#  'mrisc_top' 'aes_core' 'Sha3BlackBox' 'fpu' 'RsEncodeTop' 'sdram'
#  'dynamic_node_top_wrap' 'RsDecodeTop' 'picosoc' 'mips_core' 'pcm_slv_top'
#  'des3' 'mc_top' 'aes_cipher_top' 'wb_dma_top' 'plic_core' 'sha256'
#  'dft_top']
# Тестовые блоки: ['Top_PipelinedCipher']
# Тренировочные samples: 486641
# Тестовые samples: 78257
# MSE: 1.4204
# MAE: 0.6048
# R²: 0.9188
#
# --- Фолд 3 ---
# Тренировочные блоки: ['simple_spi_top' 'jpeg_encoder' 'FIR_filter' 'rs_encode' 'sasc_top'
#  'usb_phy' 'Network' 'Top_PipelinedCipher' 'wb_conmax_top' 'ac97_top'
#  'RocketTile' 'psram_core' 'pci_bridge32' 'spi_top' 'vga_enh_top'
#  'risc16f84_clk2x' 'aes128_core' 'mrisc_top' 'aes_core' 'Sha3BlackBox'
#  'fpu' 'RsEncodeTop' 'sdram' 'dynamic_node_top_wrap' 'RsDecodeTop'
#  'picosoc' 'mips_core' 'pcm_slv_top' 'des3' 'mc_top' 'aes_cipher_top'
#  'wb_dma_top' 'plic_core' 'sha256']
# Тестовые блоки: ['dft_top']
# Тренировочные samples: 498822
# Тестовые samples: 66076
# MSE: 7.1671
# MAE: 0.5285
# R²: 0.9134
#
# --- Фолд 4 ---
# Тренировочные блоки: ['simple_spi_top' 'jpeg_encoder' 'FIR_filter' 'rs_encode' 'usb_phy'
#  'Network' 'Top_PipelinedCipher' 'wb_conmax_top' 'ac97_top' 'RocketTile'
#  'psram_core' 'pci_bridge32' 'aes128_core' 'mrisc_top' 'Sha3BlackBox'
#  'fpu' 'RsEncodeTop' 'sdram' 'RsDecodeTop' 'picosoc' 'mips_core'
#  'pcm_slv_top' 'des3' 'aes_cipher_top' 'wb_dma_top' 'plic_core' 'sha256'
#  'dft_top']
# Тестовые блоки: ['sasc_top' 'spi_top' 'vga_enh_top' 'risc16f84_clk2x' 'aes_core'
#  'dynamic_node_top_wrap' 'mc_top']
# Тренировочные samples: 513797
# Тестовые samples: 51101
# MSE: 2.0631
# MAE: 0.4651
# R²: 0.9623
#
# --- Фолд 5 ---
# Тренировочные блоки: ['simple_spi_top' 'jpeg_encoder' 'FIR_filter' 'sasc_top' 'Network'
#  'Top_PipelinedCipher' 'wb_conmax_top' 'ac97_top' 'pci_bridge32' 'spi_top'
#  'vga_enh_top' 'risc16f84_clk2x' 'aes128_core' 'mrisc_top' 'aes_core'
#  'RsEncodeTop' 'sdram' 'dynamic_node_top_wrap' 'RsDecodeTop' 'mips_core'
#  'des3' 'mc_top' 'aes_cipher_top' 'wb_dma_top' 'plic_core' 'dft_top']
# Тестовые блоки: ['rs_encode' 'usb_phy' 'RocketTile' 'psram_core' 'Sha3BlackBox' 'fpu'
#  'picosoc' 'pcm_slv_top' 'sha256']
# Тренировочные samples: 513649
# Тестовые samples: 51249
# MSE: 3.4979
# MAE: 0.5545
# R²: 0.9420
#
# --- Фолд 6 ---
# Тренировочные блоки: ['rs_encode' 'sasc_top' 'usb_phy' 'Network' 'Top_PipelinedCipher'
#  'wb_conmax_top' 'RocketTile' 'psram_core' 'pci_bridge32' 'spi_top'
#  'vga_enh_top' 'risc16f84_clk2x' 'mrisc_top' 'aes_core' 'Sha3BlackBox'
#  'fpu' 'sdram' 'dynamic_node_top_wrap' 'RsDecodeTop' 'picosoc' 'mips_core'
#  'pcm_slv_top' 'des3' 'mc_top' 'wb_dma_top' 'sha256' 'dft_top']
# Тестовые блоки: ['simple_spi_top' 'jpeg_encoder' 'FIR_filter' 'ac97_top' 'aes128_core'
#  'RsEncodeTop' 'aes_cipher_top' 'plic_core']
# Тренировочные samples: 513775
# Тестовые samples: 51123
# MSE: 0.7790
# MAE: 0.3857
# R²: 0.9677
#
# --- Фолд 7 ---
# Тренировочные блоки: ['simple_spi_top' 'jpeg_encoder' 'FIR_filter' 'rs_encode' 'sasc_top'
#  'usb_phy' 'Network' 'Top_PipelinedCipher' 'ac97_top' 'RocketTile'
#  'psram_core' 'spi_top' 'vga_enh_top' 'risc16f84_clk2x' 'aes128_core'
#  'aes_core' 'Sha3BlackBox' 'fpu' 'RsEncodeTop' 'dynamic_node_top_wrap'
#  'picosoc' 'pcm_slv_top' 'mc_top' 'aes_cipher_top' 'plic_core' 'sha256'
#  'dft_top']
# Тестовые блоки: ['wb_conmax_top' 'pci_bridge32' 'mrisc_top' 'sdram' 'RsDecodeTop'
#  'mips_core' 'des3' 'wb_dma_top']
# Тренировочные samples: 513592
# Тестовые samples: 51306
# MSE: 16.3397
# MAE: 0.9803
# R²: 0.8661
#
# ==================================================
# ИТОГИ КРОСС-ВАЛИДАЦИИ
# ==================================================
# Среднее MSE: 6.3006 (±5.6616)
# Среднее MAE: 0.6298 (±0.2049)
# Среднее R²: 0.9242 (±0.0334)
#
# Важность фичей (средняя по фолдам):
#               feature  importance
# 2                hpwl    0.853037
# 0              fanout    0.069574
# 8    wireload_fan_cap    0.040345
# 1         fanout_area    0.012264
# 7             pin_cap    0.009555
# 9   wireload_hpwl_cap    0.006763
# 6         hpwl_stddev    0.003303
# 5           hpwl_mean    0.001627
# 10         gcell_area    0.001368
# 3            hpwl_min    0.001200
# 4            hpwl_max    0.000966
# Обучение финальной модели на всех данных...
# Финальная модель обучена!

# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
from sklearn.preprocessing import StandardScaler

# get blocks
dataset_path = './dataset/'
items = os.listdir(dataset_path)
blocks = [item for item in items if os.path.isdir(os.path.join(dataset_path, item))]

df_blocks_list = []
block_names = []

for block in blocks:
    # get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/net_feat.csv", sep=';')

    # drop all nets with zero capacitence
    df = df[df['cap'] != 0]
    df = df[df['pin_cap'] != 0]

    # drop all Nan rows
    df = df.dropna()

    # drop net name column
    df = df.drop(columns=['net'], axis=1)
    
    # Add block identifier
    df['block_id'] = block
    
    # append df to common df
    df_blocks_list.append(df)
    block_names.append(block)

# create common df
df = pd.concat(df_blocks_list, ignore_index=True)

# transfer capacintece from pF to fF
df['cap'] = df['cap'] * 1000
df['pin_cap'] = df['pin_cap'] * 1000
df['wireload_fan_cap'] = df['wireload_fan_cap'] * 1000
df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] * 1000

# add block area feature
df['block_area'] = df['block_width'] * df['block_height']

# add area feature
df['gcell_area'] = (df['urx'] - df['llx']) * (df['ury'] - df['lly'])

# add aspect ration feat
df['gcell_ar'] = (df['urx'] - df['llx']) / (df['ury'] - df['lly'])

df['abs_x'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']
df['abs_y'] = (((df['ury'] - df['lly']) / 2) + df['lly']) / df['block_height']

df['dist_to_right'] = ((df['block_width'] - ((df['urx'] - df['llx']) / 2) + df['llx'])) / df['block_width']
df['dist_to_left'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']

df['dist_to_top'] = (df['block_height'] - (((df['ury'] - df['lly']) / 2) + df['lly'])) / df['block_height']
df['dist_to_bottom'] = ((((df['ury'] - df['lly']) / 2) + df['lly']))

# ration wire cap / pin cap
# df ['wire_to_pin_cap_ratio'] = df['cap'] / df['pin_cap'] 

# drop metal segs
df = df.drop(columns=['m2_segs', 'm3_segs', 'm4_segs', 'm5_segs', 'm6_segs', 'm7_segs'])

# drop all labels except cap
df = df.drop(columns=['length', 'vias', 'segs'])

# Определяем фичи и таргет
#features = [col for col in df.columns if col not in ['cap', 'block_id']]
features = ['fanin', 'fanout', 'fanin_area', 'fanout_area', 'hpwl', 'hpwl_min', 'hpwl_max', 'hpwl_mean', 'hpwl_stddev', 'cell_density', 'pin_cap', 'wireload_fan_cap', 'wireload_hpwl_cap', 'gcell_area', 'gcell_ar']
X = df[features]
y = df['cap']
groups = df['block_id']

# Проверяем количество уникальных блоков
unique_blocks = df['block_id'].unique()
print(f"Всего уникальных блоков: {len(unique_blocks)}")

# Создаем кастомную стратегию для 7 фолдов (30 train / 5 test)
n_splits = 7
n_blocks_total = len(unique_blocks)
n_test_blocks = 5
n_train_blocks = n_blocks_total - n_test_blocks

print(f"Всего блоков: {n_blocks_total}")
print(f"Количество фолдов: {n_splits}")
print(f"Блоков в обучении на фолд: {n_train_blocks}")
print(f"Блоков в тесте на фолд: {n_test_blocks}")

# Случайно перемешиваем блоки для разнообразия фолдов
np.random.seed(42)
shuffled_blocks = np.random.permutation(unique_blocks)

# Метрики для хранения результатов
mse_scores = []
mae_scores = []
mape_scores = []
r2_scores = []
feature_importances = []

# Кастомная кросс-валидация по блокам
for fold in range(n_splits):
    print(f"\n--- Фолд {fold + 1} ---")
    
    # Вычисляем индексы для тестовых блоков (скользящее окно)
    start_idx = fold * n_test_blocks
    end_idx = start_idx + n_test_blocks
    
    # Если вышли за границы, начинаем сначала
    if end_idx > n_blocks_total:
        start_idx = 0
        end_idx = n_test_blocks
    
    test_blocks = shuffled_blocks[start_idx:end_idx]
    train_blocks = np.array([block for block in shuffled_blocks if block not in test_blocks])
    
    print(f"Тренировочные блоки ({len(train_blocks)}): {train_blocks}")
    print(f"Тестовые блоки ({len(test_blocks)}): {test_blocks}")
    
    # Создаем маски для train/test
    train_mask = df['block_id'].isin(train_blocks)
    test_mask = df['block_id'].isin(test_blocks)
    
    X_train, X_test = X[train_mask], X[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]
    
    print(f"Тренировочные samples: {len(X_train)}")
    print(f"Тестовые samples: {len(X_test)}")
    
    # Масштабирование фичей
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Обучаем XGBoost
    model = xgb.XGBRegressor(
        n_estimators=100,
        max_depth=10,
        learning_rate=0.1,
        random_state=42
    )
    
    model.fit(X_train_scaled, y_train)
    
    # Предсказания
    y_pred = model.predict(X_test_scaled)
    
    # Вычисляем метрики
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)
    r2_scores.append(r2)
    
    # Сохраняем важность фичей
    feature_importances.append(model.feature_importances_)
    
    print(f"MSE: {mse:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"MAPE: {mape:.4f}")
    print(f"R²: {r2:.4f}")

# Выводим итоговые результаты
print("\n" + "="*50)
print("ИТОГИ КРОСС-ВАЛИДАЦИИ")
print("="*50)
print(f"Среднее MSE: {np.mean(mse_scores):.4f} (±{np.std(mse_scores):.4f})")
print(f"Среднее MAE: {np.mean(mae_scores):.4f} (±{np.std(mae_scores):.4f})")
print(f"Среднее MAPE: {np.mean(mape_scores):.4f} (±{np.std(mape_scores):.4f})")
print(f"Среднее R²: {np.mean(r2_scores):.4f} (±{np.std(r2_scores):.4f})")

# Анализ важности фичей
avg_feature_importance = np.mean(feature_importances, axis=0)
feature_importance_df = pd.DataFrame({
    'feature': features,
    'importance': avg_feature_importance
}).sort_values('importance', ascending=False)

print("\nВажность фичей (средняя по фолдам):")
print(feature_importance_df)

# Визуализация важности фичей (опционально)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['feature'], feature_importance_df['importance'])
plt.xlabel('Важность')
plt.title('Средняя важность фичей по фолдам')
plt.tight_layout()
plt.show()

# Обучение финальной модели на всех данных (опционально)
print("\nОбучение финальной модели на всех данных...")
final_scaler = StandardScaler()
X_scaled = final_scaler.fit_transform(X)

final_model = xgb.XGBRegressor(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    random_state=42
)
final_model.fit(X_scaled, y)

print("Финальная модель обучена!")
# Out:
# Всего уникальных блоков: 35
# Всего блоков: 35
# Количество фолдов: 7
# Блоков в обучении на фолд: 30
# Блоков в тесте на фолд: 5
#
# --- Фолд 1 ---
# Тренировочные блоки (30): ['mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x']
# Тренировочные samples: 537593
# Тестовые samples: 27305
# MSE: 1.3345
# MAE: 0.4101
# MAPE: 0.0940
# R²: 0.9676
#
# --- Фолд 2 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core']
# Тренировочные samples: 514061
# Тестовые samples: 50837
# MSE: 22.6435
# MAE: 1.2495
# MAPE: 0.1397
# R²: 0.8291
#
# --- Фолд 3 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'pcm_slv_top' 'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter'
#  'plic_core' 'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap'
#  'wb_dma_top' 'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu'
#  'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top']
# Тренировочные samples: 556035
# Тестовые samples: 8863
# MSE: 3.3877
# MAE: 0.4824
# MAPE: 0.1257
# R²: 0.8864
#
# --- Фолд 4 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['pcm_slv_top' 'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter']
# Тренировочные samples: 541474
# Тестовые samples: 23424
# MSE: 0.5648
# MAE: 0.2802
# MAPE: 0.1108
# R²: 0.9709
#
# --- Фолд 5 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'RocketTile' 'sdram'
#  'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top' 'Top_PipelinedCipher'
#  'vga_enh_top' 'des3']
# Тестовые блоки (5): ['plic_core' 'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap'
#  'wb_dma_top']
# Тренировочные samples: 547156
# Тестовые samples: 17742
# MSE: 0.9104
# MAE: 0.4273
# MAPE: 0.0937
# R²: 0.9708
#
# --- Фолд 6 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top' 'fpu'
#  'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network']
# Тренировочные samples: 314309
# Тестовые samples: 250589
# MSE: 9.0424
# MAE: 0.7388
# MAPE: 0.0783
# R²: 0.9227
#
# --- Фолд 7 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network']
# Тестовые блоки (5): ['fpu' 'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тренировочные samples: 378760
# Тестовые samples: 186138
# MSE: 2.9101
# MAE: 0.4872
# MAPE: 0.0838
# R²: 0.9405
#
# ==================================================
# ИТОГИ КРОСС-ВАЛИДАЦИИ
# ==================================================
# Среднее MSE: 5.8276 (±7.3644)
# Среднее MAE: 0.5822 (±0.3009)
# Среднее MAPE: 0.1037 (±0.0209)
# Среднее R²: 0.9269 (±0.0492)
#
# Важность фичей (средняя по фолдам):
#               feature  importance
# 4                hpwl    0.884887
# 1              fanout    0.055647
# 11   wireload_fan_cap    0.019094
# 3         fanout_area    0.013304
# 12  wireload_hpwl_cap    0.008898
# 10            pin_cap    0.003909
# 9        cell_density    0.002354
# 2          fanin_area    0.002204
# 14           gcell_ar    0.002151
# 0               fanin    0.001991
# 8         hpwl_stddev    0.001329
# 7           hpwl_mean    0.001229
# 6            hpwl_max    0.001152
# 13         gcell_area    0.000966
# 5            hpwl_min    0.000886
# Обучение финальной модели на всех данных...
# Финальная модель обучена!

# %%
#get predicted wire load for blocks

# get blocks
dataset_path = './dataset/'
#items = os.listdir(dataset_path)
#blocks = [item for item in items if os.path.isdir(os.path.join(dataset_path, item))]

#blocks = ['dft_top']

df_blocks_list = []
block_names = []

for block in blocks:
    # get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/net_feat.csv", sep=';')

    # drop all nets with zero capacitence
    df = df[df['cap'] != 0]
    df = df[df['pin_cap'] != 0]

    # drop all Nan rows
    df = df.dropna()

    # drop net name column
    #df = df.drop(columns=['net'], axis=1)
    
    # Add block identifier
    df['block_id'] = block
    
    # append df to common df
    df_blocks_list.append(df)
    block_names.append(block)

# create common df
df = pd.concat(df_blocks_list, ignore_index=True)

# transfer capacintece from pF to fF
df['cap'] = df['cap'] * 1000
df['pin_cap'] = df['pin_cap'] * 1000
df['wireload_fan_cap'] = df['wireload_fan_cap'] * 1000
df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] * 1000

# add block area feature
df['block_area'] = df['block_width'] * df['block_height']

# add area feature
df['gcell_area'] = (df['urx'] - df['llx']) * (df['ury'] - df['lly'])

# add aspect ration feat
df['gcell_ar'] = (df['urx'] - df['llx']) / (df['ury'] - df['lly'])

features = ['fanin', 'fanout', 'fanin_area', 'fanout_area', 'hpwl', 'hpwl_min', 'hpwl_max', 'hpwl_mean', 'hpwl_stddev', 'cell_density', 'pin_cap', 'wireload_fan_cap', 'wireload_hpwl_cap', 'gcell_area', 'gcell_ar']

x = df[features]
x = final_scaler.transform(x)

y_pred = model.predict(x)
df['predicted_cap'] = y_pred
#y_real = df['cap']

#mape = mean_absolute_percentage_error(y_pred, y_real)
#mape

# %%
df
# Out:
#                                           net  block_width  block_height  \
# 0      FE_PDN1297_stage14_instPerm80231_s1_11       854.14         854.0
# 1       FE_PDN1296_stage14_instPerm80231_s1_5       854.14         854.0
# 2      FE_PDN1295_stage14_instPerm80231_s1_25       854.14         854.0
# 3       FE_PDN1294_stage14_instPerm80231_s1_1       854.14         854.0
# 4      FE_PDN1293_stage14_instPerm80231_s1_29       854.14         854.0
# ...                                       ...          ...           ...
# 66071                                   X3[4]       854.14         854.0
# 66072                                   X3[3]       854.14         854.0
# 66073                                   X3[2]       854.14         854.0
# 66074                                   X3[1]       854.14         854.0
# 66075                                   X3[0]       854.14         854.0
#
#        fanin  fanout  fanin_area  fanout_area     llx     lly     urx  ...  \
# 0          1      59      1.4112     152.6448  401.94  663.04  557.90  ...
# 1          1      61      1.4112     157.8192  428.26  673.12  572.18  ...
# 2          1      61      1.4112     157.8192  420.28  694.96  564.34  ...
# 3          1      60      1.4112     155.2320  404.32  673.12  561.26  ...
# 4          1      61      1.4112     157.8192  422.94  686.56  564.20  ...
# ...      ...     ...         ...          ...     ...     ...     ...  ...
# 66071      0      64      0.0000     165.5808    0.00  367.36  210.70  ...
# 66072      0      64      0.0000     165.5808    0.00  362.32  154.98  ...
# 66073      0      64      0.0000     165.5808    0.00  369.04  214.34  ...
# 66074      0      64      0.0000     165.5808    0.00  365.68  141.68  ...
# 66075      0      64      0.0000     165.5808    0.00  369.04  208.60  ...
#
#        m7_segs  length  segs  vias   cap  block_id  block_area  gcell_area  \
# 0            0  265.58   295   117  38.0   dft_top   729435.56    524.0256
# 1            0  274.68   277   124  40.0   dft_top   729435.56    967.1424
# 2            0  283.64   302   137  39.0   dft_top   729435.56   1210.1040
# 3            0  294.98   318   130  40.0   dft_top   729435.56   2636.5920
# 4            0  272.30   265   134  37.0   dft_top   729435.56    474.6336
# ...        ...     ...   ...   ...   ...       ...         ...         ...
# 66071        0  588.56   350   166  72.0   dft_top   729435.56  17905.2860
# 66072        0  520.38   367   176  67.0   dft_top   729435.56  14038.0884
# 66073        0  584.78   337   168  73.0   dft_top   729435.56  18094.5828
# 66074        0  456.26   368   166  61.0   dft_top   729435.56  12516.0112
# 66075        0  627.48   371   183  76.0   dft_top   729435.56  17843.6440
#
#         gcell_ar  predicted_cap
# 0      46.416667      41.159512
# 1      21.416667      42.154819
# 2      17.150000      39.802635
# 3       9.341667      39.569351
# 4      42.041667      42.350388
# ...          ...            ...
# 66071   2.479407      60.096355
# 66072   1.710974      51.577831
# 66073   2.538972      59.873646
# 66074   1.603803      51.322815
# 66075   2.438625      59.709396
#
# [66076 rows x 35 columns]

# %%
import pandas as pd

# Предполагаем, что у вас есть DataFrame df с нужными колонками
# df = pd.DataFrame(...)

# Создаем директорию для файлов если нужно
import os
os.makedirs('load_files', exist_ok=True)

# Функция для создания файла с командами set_load
def create_load_file(df, cap_column, filename):
    """
    Создает файл с командами set_load для указанной колонки емкостей
    
    Args:
        df: DataFrame с данными
        cap_column: название колонки с емкостями
        filename: имя выходного файла
    """
    with open(f'load_files/{filename}', 'w') as f:
        for _, row in df.iterrows():
            net_name = row['net']
            cap_value = row[cap_column]
            # Форматируем команду set_load
            command = f"set_load {cap_value} [get_db nets {net_name}]\n"
            f.write(command)
    
    print(f"✅ Файл {filename} создан: {len(df)} команд")

# Создаем 4 файла для разных типов емкостей

# 1. Файл с предсказанными емкостями
create_load_file(df, 'predicted_cap', 'predicted_loads.tcl')

# 2. Файл с реальными емкостями
create_load_file(df, 'cap', 'actual_loads.tcl')

# 3. Файл с wireload fan емкостями
create_load_file(df, 'wireload_fan_cap', 'wireload_fan_loads.tcl')

# 4. Файл с wireload hpwl емкостями
create_load_file(df, 'wireload_hpwl_cap', 'wireload_hpwl_loads.tcl')

print("\n🎯 Все 4 файла созданы в папке 'load_files':")
print("   - predicted_loads.tcl     (предсказанные емкости)")
print("   - actual_loads.tcl        (реальные емкости)")
print("   - wireload_fan_loads.tcl  (wireload fan емкости)")
print("   - wireload_hpwl_loads.tcl (wireload hpwl емкости)")
# Out:
# ✅ Файл predicted_loads.tcl создан: 66076 команд
# ✅ Файл actual_loads.tcl создан: 66076 команд
# ✅ Файл wireload_fan_loads.tcl создан: 66076 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 66076 команд
#
# 🎯 Все 4 файла созданы в папке 'load_files':
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)

# %%
##Создаем файлы с set_load для блоков из датасета
import time
# Функция для создания файла с командами set_load
def create_load_file(df, block, cap_column, filename):
    """
    Создает файл с командами set_load для указанной колонки емкостей
    
    Args:
        df: DataFrame с данными
        cap_column: название колонки с емкостями
        filename: имя выходного файла
    """
    with open(f'./dataset/{block}/{filename}', 'w') as f:
        for _, row in df.iterrows():
            net_name = row['net']
            cap_value = row[cap_column]
            # Форматируем команду set_load
            command = f"set_load {cap_value} [get_db nets {net_name}]\n"
            f.write(command)
    
    print(f"✅ Файл {filename} создан: {len(df)} команд")


# get blocks
import os
dataset_path = './dataset/'
items = os.listdir(dataset_path)
blocks = [item for item in items if os.path.isdir(os.path.join(dataset_path, item))]
features = ['fanin', 'fanout', 'fanin_area', 'fanout_area', 'hpwl', 'hpwl_min', 'hpwl_max', 'hpwl_mean', 'hpwl_stddev', 'cell_density', 'pin_cap', 'wireload_fan_cap', 'wireload_hpwl_cap', 'gcell_area', 'gcell_ar']

#iter for each block

for block in blocks:

    # начальное время
    start_time = time.time()
    
    # get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/net_feat.csv", sep=';')

    # drop all nets with zero capacitence
    df = df[df['cap'] != 0]
    df = df[df['pin_cap'] != 0]

    # drop all Nan rows
    df = df.dropna()

    # transfer capacintece from pF to fF
    df['cap'] = df['cap'] * 1000
    df['pin_cap'] = df['pin_cap'] * 1000
    df['wireload_fan_cap'] = df['wireload_fan_cap'] * 1000
    df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] * 1000

    # add block area feature
    df['block_area'] = df['block_width'] * df['block_height']

    # add area feature
    df['gcell_area'] = (df['urx'] - df['llx']) * (df['ury'] - df['lly'])

    # add aspect ration feat
    df['gcell_ar'] = (df['urx'] - df['llx']) / (df['ury'] - df['lly'])

    x = df[features]
    x = final_scaler.transform(x)

    y_pred = model.predict(x)
    df['predicted_cap'] = y_pred

    # transfer capacintece from fF to pF
    df['cap'] = df['cap'] / 1000
    df['pin_cap'] = df['pin_cap'] / 1000
    df['wireload_fan_cap'] = df['wireload_fan_cap'] / 1000
    df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] / 1000
    df['predicted_cap'] = df['predicted_cap'] / 1000

    # 1. Файл с предсказанными емкостями
    create_load_file(df, block, 'predicted_cap', 'predicted_loads.tcl')

    # 2. Файл с реальными емкостями
    create_load_file(df, block, 'cap', 'actual_loads.tcl')

    # 3. Файл с wireload fan емкостями
    create_load_file(df, block, 'wireload_fan_cap', 'wireload_fan_loads.tcl')

    # 4. Файл с wireload hpwl емкостями
    create_load_file(df, block, 'wireload_hpwl_cap', 'wireload_hpwl_loads.tcl')

    end_time = time.time()

    # разница между конечным и начальным временем
    elapsed_time = end_time - start_time
    print('Elapsed time: ', elapsed_time)

    print(f"\n🎯 Все 4 файла созданы в папке 'dataset/block' для блока {block}:")
    print("   - predicted_loads.tcl     (предсказанные емкости)")
    print("   - actual_loads.tcl        (реальные емкости)")
    print("   - wireload_fan_loads.tcl  (wireload fan емкости)")
    print("   - wireload_hpwl_loads.tcl (wireload hpwl емкости)")
# Out:
# ✅ Файл predicted_loads.tcl создан: 285 команд
# ✅ Файл actual_loads.tcl создан: 285 команд
# ✅ Файл wireload_fan_loads.tcl создан: 285 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 285 команд
# Elapsed time:  0.06307172775268555
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока simple_spi_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 21221 команд
# ✅ Файл actual_loads.tcl создан: 21221 команд
# ✅ Файл wireload_fan_loads.tcl создан: 21221 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 21221 команд
# Elapsed time:  3.329378604888916
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока jpeg_encoder:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 1164 команд
# ✅ Файл actual_loads.tcl создан: 1164 команд
# ✅ Файл wireload_fan_loads.tcl создан: 1164 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 1164 команд
# Elapsed time:  0.1839127540588379
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока FIR_filter:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 1127 команд
# ✅ Файл actual_loads.tcl создан: 1127 команд
# ✅ Файл wireload_fan_loads.tcl создан: 1127 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 1127 команд
# Elapsed time:  0.1819751262664795
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока rs_encode:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 260 команд
# ✅ Файл actual_loads.tcl создан: 260 команд
# ✅ Файл wireload_fan_loads.tcl создан: 260 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 260 команд
# Elapsed time:  0.049289703369140625
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока sasc_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 192 команд
# ✅ Файл actual_loads.tcl создан: 192 команд
# ✅ Файл wireload_fan_loads.tcl создан: 192 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 192 команд
# Elapsed time:  0.03802084922790527
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока usb_phy:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 215786 команд
# ✅ Файл actual_loads.tcl создан: 215786 команд
# ✅ Файл wireload_fan_loads.tcl создан: 215786 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 215786 команд
# Elapsed time:  35.00722074508667
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока Network:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 78257 команд
# ✅ Файл actual_loads.tcl создан: 78257 команд
# ✅ Файл wireload_fan_loads.tcl создан: 78257 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 78257 команд
# Elapsed time:  12.53334355354309
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока Top_PipelinedCipher:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 16092 команд
# ✅ Файл actual_loads.tcl создан: 16092 команд
# ✅ Файл wireload_fan_loads.tcl создан: 16092 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 16092 команд
# Elapsed time:  2.601625442504883
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока wb_conmax_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 3851 команд
# ✅ Файл actual_loads.tcl создан: 3851 команд
# ✅ Файл wireload_fan_loads.tcl создан: 3851 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 3851 команд
# Elapsed time:  0.6274640560150146
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока ac97_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 2389 команд
# ✅ Файл actual_loads.tcl создан: 2389 команд
# ✅ Файл wireload_fan_loads.tcl создан: 2389 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 2389 команд
# Elapsed time:  0.3869669437408447
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока RocketTile:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 698 команд
# ✅ Файл actual_loads.tcl создан: 698 команд
# ✅ Файл wireload_fan_loads.tcl создан: 698 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 698 команд
# Elapsed time:  0.11811590194702148
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока psram_core:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 6507 команд
# ✅ Файл actual_loads.tcl создан: 6507 команд
# ✅ Файл wireload_fan_loads.tcl создан: 6507 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 6507 команд
# Elapsed time:  1.0499985218048096
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока pci_bridge32:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 1012 команд
# ✅ Файл actual_loads.tcl создан: 1012 команд
# ✅ Файл wireload_fan_loads.tcl создан: 1012 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 1012 команд
# Elapsed time:  0.16390347480773926
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока spi_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 31564 команд
# ✅ Файл actual_loads.tcl создан: 31564 команд
# ✅ Файл wireload_fan_loads.tcl создан: 31564 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 31564 команд
# Elapsed time:  5.059682846069336
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока vga_enh_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 729 команд
# ✅ Файл actual_loads.tcl создан: 729 команд
# ✅ Файл wireload_fan_loads.tcl создан: 729 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 729 команд
# Elapsed time:  0.12275481224060059
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока risc16f84_clk2x:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 14350 команд
# ✅ Файл actual_loads.tcl создан: 14350 команд
# ✅ Файл wireload_fan_loads.tcl создан: 14350 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 14350 команд
# Elapsed time:  2.30448842048645
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока aes128_core:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 560 команд
# ✅ Файл actual_loads.tcl создан: 560 команд
# ✅ Файл wireload_fan_loads.tcl создан: 560 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 560 команд
# Elapsed time:  0.09824728965759277
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока mrisc_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 9482 команд
# ✅ Файл actual_loads.tcl создан: 9482 команд
# ✅ Файл wireload_fan_loads.tcl создан: 9482 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 9482 команд
# Elapsed time:  1.507012128829956
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока aes_core:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 11512 команд
# ✅ Файл actual_loads.tcl создан: 11512 команд
# ✅ Файл wireload_fan_loads.tcl создан: 11512 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 11512 команд
# Elapsed time:  1.8457307815551758
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока Sha3BlackBox:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 8831 команд
# ✅ Файл actual_loads.tcl создан: 8831 команд
# ✅ Файл wireload_fan_loads.tcl создан: 8831 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 8831 команд
# Elapsed time:  1.4785921573638916
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока fpu:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 613 команд
# ✅ Файл actual_loads.tcl создан: 613 команд
# ✅ Файл wireload_fan_loads.tcl создан: 613 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 613 команд
# Elapsed time:  0.10541796684265137
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока RsEncodeTop:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 488 команд
# ✅ Файл actual_loads.tcl создан: 488 команд
# ✅ Файл wireload_fan_loads.tcl создан: 488 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 488 команд
# Elapsed time:  0.08446407318115234
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока sdram:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 5678 команд
# ✅ Файл actual_loads.tcl создан: 5678 команд
# ✅ Файл wireload_fan_loads.tcl создан: 5678 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 5678 команд
# Elapsed time:  0.9460964202880859
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока dynamic_node_top_wrap:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 19974 команд
# ✅ Файл actual_loads.tcl создан: 19974 команд
# ✅ Файл wireload_fan_loads.tcl создан: 19974 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 19974 команд
# Elapsed time:  3.2942087650299072
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока RsDecodeTop:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 22444 команд
# ✅ Файл actual_loads.tcl создан: 22444 команд
# ✅ Файл wireload_fan_loads.tcl создан: 22444 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 22444 команд
# Elapsed time:  3.6362431049346924
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока picosoc:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 4977 команд
# ✅ Файл actual_loads.tcl создан: 4977 команд
# ✅ Файл wireload_fan_loads.tcl создан: 4977 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 4977 команд
# Elapsed time:  0.7938966751098633
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока mips_core:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 149 команд
# ✅ Файл actual_loads.tcl создан: 149 команд
# ✅ Файл wireload_fan_loads.tcl создан: 149 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 149 команд
# Elapsed time:  0.03411555290222168
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока pcm_slv_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 1410 команд
# ✅ Файл actual_loads.tcl создан: 1410 команд
# ✅ Файл wireload_fan_loads.tcl создан: 1410 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 1410 команд
# Elapsed time:  0.23563861846923828
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока des3:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 2376 команд
# ✅ Файл actual_loads.tcl создан: 2376 команд
# ✅ Файл wireload_fan_loads.tcl создан: 2376 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 2376 команд
# Elapsed time:  0.39702868461608887
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока mc_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 7907 команд
# ✅ Файл actual_loads.tcl создан: 7907 команд
# ✅ Файл wireload_fan_loads.tcl создан: 7907 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 7907 команд
# Elapsed time:  1.3109683990478516
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока aes_cipher_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 1298 команд
# ✅ Файл actual_loads.tcl создан: 1298 команд
# ✅ Файл wireload_fan_loads.tcl создан: 1298 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 1298 команд
# Elapsed time:  0.22553586959838867
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока wb_dma_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 1732 команд
# ✅ Файл actual_loads.tcl создан: 1732 команд
# ✅ Файл wireload_fan_loads.tcl создан: 1732 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 1732 команд
# Elapsed time:  0.28562259674072266
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока plic_core:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 3907 команд
# ✅ Файл actual_loads.tcl создан: 3907 команд
# ✅ Файл wireload_fan_loads.tcl создан: 3907 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 3907 команд
# Elapsed time:  0.6376981735229492
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока sha256:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)
# ✅ Файл predicted_loads.tcl создан: 66076 команд
# ✅ Файл actual_loads.tcl создан: 66076 команд
# ✅ Файл wireload_fan_loads.tcl создан: 66076 команд
# ✅ Файл wireload_hpwl_loads.tcl создан: 66076 команд
# Elapsed time:  10.841742753982544
#
# 🎯 Все 4 файла созданы в папке 'dataset/block' для блока dft_top:
#    - predicted_loads.tcl     (предсказанные емкости)
#    - actual_loads.tcl        (реальные емкости)
#    - wireload_fan_loads.tcl  (wireload fan емкости)
#    - wireload_hpwl_loads.tcl (wireload hpwl емкости)

# %%
# get blocks
import os
dataset_path = './dataset/'
items = os.listdir(dataset_path)
blocks = [item for item in items if os.path.isdir(os.path.join(dataset_path, item))]
#features = ['fanin', 'fanout', 'fanin_area', 'fanout_area', 'hpwl', 'hpwl_min', 'hpwl_max', 'hpwl_mean', 'hpwl_stddev', 'cell_density', 'pin_cap', 'wireload_fan_cap', 'wireload_hpwl_cap', 'gcell_area', 'gcell_ar']


df_blocks_list = []
block_names = []

for block in blocks:
    # get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/wns.csv", sep=';')
    #df
    #safe_regression_metrics(df['wns_spef'], df['wns_model_predicted'])
    #mae = mean_absolute_error(df['wns_spef'], df['wns_model_predicted'])
    #print(mae)
    
    # append df to common df
    df_blocks_list.append(df)
    block_names.append(block)

# create common df
df = pd.concat(df_blocks_list, ignore_index=True)

# %%
#df['wns_spef'].values

df['clock_period'].tolist()

#y_real = df['wns_spef']
#y_model_predicted = df['wns_model_predicted']
#y_wireload_fan = df['wns_wireload_fan']
# Out:
# [5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  30.0,
#  5.0,
#  30.0,
#  5.0,
#  30.0,
#  5.0,
#  2.5,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  30.0,
#  5.0]

# %%
p_values = {
    'F_spef vs F_early_route': 0.032,
    'F_spef vs F_ml_model': 0.0008, 
    'F_spef vs F_wireload': 0.0
}

def interpret_frequency_ttest(p_values):
    print("📊 СТАТИСТИЧЕСКИЙ АНАЛИЗ ЧАСТОТ СХЕМЫ")
    print("=" * 60)
    print("ГИПОТЕЗЫ:")
    print("H₀: Средние частоты РАВНЫ (метод не влияет на частоту)")
    print("H₁: Средние частоты НЕ РАВНЫ (метод влияет на частоту)")
    print("=" * 60)
    
    for comparison, p_value in p_values.items():
        method = comparison.split('vs ')[1]
        
        if p_value < 0.001:
            significance = "***"
            strength = "ОЧЕНЬ ВЫСОКАЯ"
        elif p_value < 0.01:
            significance = "**" 
            strength = "ВЫСОКАЯ"
        elif p_value < 0.05:
            significance = "*"
            strength = "СТАТИСТИЧЕСКАЯ"
        else:
            significance = "ns"
            strength = "НЕТ"
        
        print(f"\n{comparison}:")
        print(f"  p-value = {p_value:.6f} {significance}")
        
        if p_value < 0.05:
            print(f"  ✅ ОТКЛОНЯЕМ H₀: {strength} значимость")
            print(f"  → Метод {method} дает СТАТИСТИЧЕСКИ ЗНАЧИМО другую частоту")
        else:
            print(f"  ❌ НЕ ОТКЛОНЯЕМ H₀: {strength} значимость")
            print(f"  → Метод {method} дает СХОЖУЮ частоту со Spef")

interpret_frequency_ttest(p_values)

def generate_frequency_conclusions(p_values):
    print("\n🎯 КЛЮЧЕВЫЕ СТАТИСТИЧЕСКИЕ ВЫВОДЫ")
    print("=" * 50)
    
    # Чем БОЛЬШЕ p-value, тем ЛУЧШЕ (ближе к Spef)
    methods_ranking = sorted(p_values.items(), key=lambda x: x[1], reverse=True)
    
    best_method = methods_ranking[-1][0].split('vs ')[1]  # Наименьший p-value
    worst_method = methods_ranking[0][0].split('vs ')[1]  # Наибольший p-value
    
    print("1. ВСЕ методы дают статистически значимо разные частоты от Spef")
    print("   Это означает: оценка емкости СУЩЕСТВЕННО влияет на итоговую частоту")
    
    print(f"\n2. Наиболее отличающийся метод: {worst_method}")
    print(f"   Наименее отличающийся метод: {best_method}")
    
    # Сравнение ML и Wireload
    ml_p = p_values['F_spef vs F_ml_model']
    wl_p = p_values['F_spef vs F_wireload']
    
    if ml_p > wl_p:
        advantage = "ЛУЧШЕ (ближе к Spef)"
    else:
        advantage = "ХУЖЕ (дальше от Spef)"
        
    print(f"\n3. ML модель против Wireload:")
    print(f"   • ML: p = {ml_p:.6f}")
    print(f"   • Wireload: p = {wl_p:.6f}")
    print(f"   • ML модель {advantage} чем Wireload")

generate_frequency_conclusions(p_values)

def generate_methodology_description():
    print("\n📝 МЕТОДОЛОГИЯ ДЛЯ СТАТЬИ")
    print("=" * 50)
    print("""
СТАТИСТИЧЕСКИЙ АНАЛИЗ:

Для количественной оценки влияния различных методов оценки 
емкостей на итоговую производительность схемы был применен 
парный t-критерий Стьюдента. 

АНАЛИЗ ПРОВОДИЛСЯ СЛЕДУЮЩИМ ОБРАЗОМ:

1. Для каждого тестового случая рассчитывались максимальные 
   рабочие частоты при использовании различных моделей емкостей:
   - F_spef (эталон, на основе точных емкостей из Spef)
   - F_early_route (ранняя оценка маршрутизации)
   - F_ml_model (емкости, предсказанные ML моделью)
   - F_wireload (емкости из wireload моделей)

2. Проводились парные сравнения каждой модели с эталоном (Spef)
   с использованием двустороннего t-критерия

3. Нулевая гипотеза (H₀): "Метод оценки емкостей не влияет на 
   итоговую частоту схемы" (средние частоты равны)

4. Альтернативная гипотеза (H₁): "Метод оценки емкостей 
   существенно влияет на частоту схемы" (средние частоты различаются)

Уровень значимости α = 0.05
""")

generate_methodology_description()
# Out:
# 📊 СТАТИСТИЧЕСКИЙ АНАЛИЗ ЧАСТОТ СХЕМЫ
# ============================================================
# ГИПОТЕЗЫ:
# H₀: Средние частоты РАВНЫ (метод не влияет на частоту)
# H₁: Средние частоты НЕ РАВНЫ (метод влияет на частоту)
# ============================================================
#
# F_spef vs F_early_route:
#   p-value = 0.032000 *
#   ✅ ОТКЛОНЯЕМ H₀: СТАТИСТИЧЕСКАЯ значимость
#   → Метод F_early_route дает СТАТИСТИЧЕСКИ ЗНАЧИМО другую частоту
#
# F_spef vs F_ml_model:
#   p-value = 0.000800 ***
#   ✅ ОТКЛОНЯЕМ H₀: ОЧЕНЬ ВЫСОКАЯ значимость
#   → Метод F_ml_model дает СТАТИСТИЧЕСКИ ЗНАЧИМО другую частоту
#
# F_spef vs F_wireload:
#   p-value = 0.000000 ***
#   ✅ ОТКЛОНЯЕМ H₀: ОЧЕНЬ ВЫСОКАЯ значимость
#   → Метод F_wireload дает СТАТИСТИЧЕСКИ ЗНАЧИМО другую частоту
#
# 🎯 КЛЮЧЕВЫЕ СТАТИСТИЧЕСКИЕ ВЫВОДЫ
# ==================================================
# 1. ВСЕ методы дают статистически значимо разные частоты от Spef
#    Это означает: оценка емкости СУЩЕСТВЕННО влияет на итоговую частоту
#
# 2. Наиболее отличающийся метод: F_early_route
#    Наименее отличающийся метод: F_wireload
#
# 3. ML модель против Wireload:
#    • ML: p = 0.000800
#    • Wireload: p = 0.000000
#    • ML модель ЛУЧШЕ (ближе к Spef) чем Wireload
#
# 📝 МЕТОДОЛОГИЯ ДЛЯ СТАТЬИ
# ==================================================
#
# СТАТИСТИЧЕСКИЙ АНАЛИЗ:
#
# Для количественной оценки влияния различных методов оценки
# емкостей на итоговую производительность схемы был применен
# парный t-критерий Стьюдента.
#
# АНАЛИЗ ПРОВОДИЛСЯ СЛЕДУЮЩИМ ОБРАЗОМ:
#
# 1. Для каждого тестового случая рассчитывались максимальные
#    рабочие частоты при использовании различных моделей емкостей:
#    - F_spef (эталон, на основе точных емкостей из Spef)
#    - F_early_route (ранняя оценка маршрутизации)
#    - F_ml_model (емкости, предсказанные ML моделью)
#    - F_wireload (емкости из wireload моделей)
#
# 2. Проводились парные сравнения каждой модели с эталоном (Spef)
#    с использованием двустороннего t-критерия
#
# 3. Нулевая гипотеза (H₀): "Метод оценки емкостей не влияет на
#    итоговую частоту схемы" (средние частоты равны)
#
# 4. Альтернативная гипотеза (H₁): "Метод оценки емкостей
#    существенно влияет на частоту схемы" (средние частоты различаются)
#
# Уровень значимости α = 0.05

# %%
import pandas as pd
import numpy as np

def safe_accuracy_calculation(wns_spef, wns_method, epsilon=1e-8):
    """
    Безопасный расчет точности с обработкой WNS = 0
    """
    if abs(wns_spef) < epsilon:  # WNS_Spef близко к 0
        if abs(wns_method) < epsilon:  # Оба близки к 0 - идеальная точность
            return 100.0
        else:  # WNS_Spef = 0, но метод имеет нарушение - плохая точность
            return 0.0
    else:
        # Обычный расчет точности
        return (1 - abs((wns_method - wns_spef) / abs(wns_spef))) * 100

def safe_improvement_calculation(wns_spef, wns_method, epsilon=1e-8):
    """
    Безопасный расчет улучшения с обработкой WNS = 0
    """
    if abs(wns_spef) < epsilon:  # WNS_Spef близко к 0
        if abs(wns_method) < epsilon:  # Оба 0 - нет улучшения/ухудшения
            return 0.0
        else:  # WNS_Spef = 0, но метод имеет нарушение - ухудшение
            return -100.0
    else:
        # Обычный расчет улучшения (чем ближе к 0, тем лучше)
        return ((wns_spef - wns_method) / abs(wns_spef)) * 100

def create_comparison_table_safe(df):
    """
    Создает основную таблицу сравнения с безопасной обработкой WNS = 0
    """
    results = []
    
    for _, row in df.iterrows():
        # Безопасный расчет точности
        early_route_acc = safe_accuracy_calculation(row['wns_spef'], row['wns_early_route'])
        model_acc = safe_accuracy_calculation(row['wns_spef'], row['wns_model_predicted'])
        wireload_fan_acc = safe_accuracy_calculation(row['wns_spef'], row['wns_wireload_fan'])
        wireload_hpwl_acc = safe_accuracy_calculation(row['wns_spef'], row['wns_wireload_hpwl'])
        
        # Безопасный расчет улучшения
        early_route_imp = safe_improvement_calculation(row['wns_spef'], row['wns_early_route'])
        model_imp = safe_improvement_calculation(row['wns_spef'], row['wns_model_predicted'])
        wireload_fan_imp = safe_improvement_calculation(row['wns_spef'], row['wns_wireload_fan'])
        wireload_hpwl_imp = safe_improvement_calculation(row['wns_spef'], row['wns_wireload_hpwl'])
        
        # Улучшение относительно худшего wireload метода
        worst_wireload_acc = min(wireload_fan_acc, wireload_hpwl_acc)
        model_vs_worst_improvement = model_acc - worst_wireload_acc
        
        # Определяем статус timing
        timing_status = "MET" if row['wns_spef'] >= -1e-8 else "VIOLATED"
        
        results.append({
            'Block': row['block'],
            'Clock_Period (ns)': row['clock_period'],
            'Timing_Status': timing_status,
            'WNS_Spef (ns)': row['wns_spef'],
            
            # Абсолютные значения WNS
            'WNS_EarlyRoute (ns)': row['wns_early_route'],
            'WNS_ML_Model (ns)': row['wns_model_predicted'],
            'WNS_Wireload_Fan (ns)': row['wns_wireload_fan'],
            'WNS_Wireload_HPWL (ns)': row['wns_wireload_hpwl'],
            
            # Точность относительно Spef (%)
            'EarlyRoute_Acc (%)': early_route_acc,
            'ML_Model_Acc (%)': model_acc,
            'Wireload_Fan_Acc (%)': wireload_fan_acc,
            'Wireload_HPWL_Acc (%)': wireload_hpwl_acc,
            
            # Улучшение относительно Spef (%)
            'EarlyRoute_Imp (%)': early_route_imp,
            'ML_Model_Imp (%)': model_imp,
            'Wireload_Fan_Imp (%)': wireload_fan_imp,
            'Wireload_HPWL_Imp (%)': wireload_hpwl_imp,
            
            # Сравнение с wireload методами
            'ML_vs_Best_Wireload (%)': model_acc - max(wireload_fan_acc, wireload_hpwl_acc),
            'ML_vs_Worst_Wireload (%)': model_vs_worst_improvement
        })
    
    results_df = pd.DataFrame(results)
    
    # Добавляем строку со средними значениями (исключая случаи с WNS = 0 для некоторых расчетов)
    mean_data = {}
    for col in results_df.columns:
        if col == 'Block':
            mean_data[col] = 'MEAN'
        elif col == 'Timing_Status':
            mean_data[col] = '—'
        elif results_df[col].dtype in [np.float64, np.int64]:
            # Для accuracy и improvement считаем mean только валидных значений
            if 'Acc' in col or 'Imp' in col or 'vs_' in col:
                valid_values = results_df[col][results_df[col].abs() < 1e6]  # Исключаем крайние значения
                if len(valid_values) > 0:
                    mean_data[col] = valid_values.mean()
                else:
                    mean_data[col] = 0.0
            else:
                mean_data[col] = results_df[col].mean()
        else:
            mean_data[col] = '—'
    
    results_df = pd.concat([results_df, pd.DataFrame([mean_data])], ignore_index=True)
    
    return results_df

# Создаем таблицу
comparison_table_safe = create_comparison_table_safe(df)

# Форматируем для красивого вывода
def format_table_safe(df):
    formatted_df = df.copy()
    
    for col in df.columns:
        if df[col].dtype in [np.float64, np.int64]:
            if 'Acc' in col or 'Imp' in col or 'vs_' in col:
                formatted_df[col] = formatted_df[col].apply(
                    lambda x: f"{x:.1f}%" if pd.notnull(x) and abs(x) < 1e6 else "N/A"
                )
            elif 'WNS' in col:
                formatted_df[col] = formatted_df[col].apply(
                    lambda x: f"{x:.3f}" if pd.notnull(x) else "N/A"
                )
            elif 'Clock' in col:
                formatted_df[col] = formatted_df[col].apply(
                    lambda x: f"{x:.2f}" if pd.notnull(x) else "N/A"
                )
    
    return formatted_df

formatted_table_safe = format_table_safe(comparison_table_safe)
print("📊 ТАБЛИЦА 1: СРАВНЕНИЕ WNS ПО МЕТОДАМ (С ОБРАБОТКОЙ WNS = 0)")
print("="*140)
print(formatted_table_safe.to_string(index=False))
# Out:
# 📊 ТАБЛИЦА 1: СРАВНЕНИЕ WNS ПО МЕТОДАМ (С ОБРАБОТКОЙ WNS = 0)
# ============================================================================================================================================
#                 Block Clock_Period (ns) Timing_Status WNS_Spef (ns) WNS_EarlyRoute (ns) WNS_ML_Model (ns) WNS_Wireload_Fan (ns) WNS_Wireload_HPWL (ns) EarlyRoute_Acc (%) ML_Model_Acc (%) Wireload_Fan_Acc (%) Wireload_HPWL_Acc (%) EarlyRoute_Imp (%) ML_Model_Imp (%) Wireload_Fan_Imp (%) Wireload_HPWL_Imp (%) ML_vs_Best_Wireload (%) ML_vs_Worst_Wireload (%)
#        simple_spi_top              5.00           MET         2.609               2.629             2.613                 2.651                  2.041              99.2%            99.8%                98.4%                 78.2%              -0.8%            -0.2%                -1.6%                 21.8%                    1.5%                    21.6%
#          jpeg_encoder              5.00           MET         1.122               1.149             1.083                -0.374                -18.228              97.6%            96.5%               -33.3%              -1624.6%              -2.4%             3.5%               133.3%               1724.6%                  129.9%                  1721.1%
#            FIR_filter              5.00      VIOLATED        -0.009               0.037            -0.098                 0.032                 -7.949            -411.1%          -888.9%              -355.6%             -88122.2%            -511.1%           988.9%              -455.6%              88222.2%                 -533.3%                 87233.3%
#             rs_encode              5.00           MET         1.460               1.525             1.454                 1.300                 -0.307              95.5%            99.6%                89.0%                -21.0%              -4.5%             0.4%                11.0%                121.0%                   10.5%                   120.6%
#              sasc_top              5.00           MET         2.587               2.566             2.569                 2.538                  1.627              99.2%            99.3%                98.1%                 62.9%               0.8%             0.7%                 1.9%                 37.1%                    1.2%                    36.4%
#               usb_phy              5.00           MET         2.878               2.864             2.871                 2.851                  2.428              99.5%            99.8%                99.1%                 84.4%               0.5%             0.2%                 0.9%                 15.6%                    0.7%                    15.4%
#               Network              5.00           MET         0.092              -0.030            -0.029                -1.220                -70.461             -32.6%           -31.5%             -1326.1%             -76588.0%             132.6%           131.5%              1426.1%              76688.0%                 1294.6%                 76556.5%
#   Top_PipelinedCipher              5.00           MET         0.590               0.693             0.670                -1.968                -26.818              82.5%            86.4%              -333.6%              -4545.4%             -17.5%           -13.6%               433.6%               4645.4%                  420.0%                  4631.9%
#         wb_conmax_top              5.00           MET         0.105               0.013            -0.001                 0.291                -14.581              12.4%            -1.0%               -77.1%             -13886.7%              87.6%           101.0%              -177.1%              13986.7%                   76.2%                 13885.7%
#              ac97_top              5.00           MET         2.189               2.220             2.195                 2.177                 -0.050              98.6%            99.7%                99.5%                 -2.3%              -1.4%            -0.3%                 0.5%                102.3%                    0.3%                   102.0%
#            RocketTile              5.00           MET         2.278               2.325             2.257                 2.056                 -2.177              97.9%            99.1%                90.3%                -95.6%              -2.1%             0.9%                 9.7%                195.6%                    8.8%                   194.6%
#            psram_core              5.00           MET         1.089               1.088             1.088                 1.103                  0.498              99.9%            99.9%                98.7%                 45.7%               0.1%             0.1%                -1.3%                 54.3%                    1.2%                    54.2%
#          pci_bridge32              5.00           MET         1.000               0.994             1.017                 1.052                 -4.402              99.4%            98.3%                94.8%               -440.2%               0.6%            -1.7%                -5.2%                540.2%                    3.5%                   538.5%
#               spi_top              5.00           MET         2.353               2.370             2.319                 2.055                  0.837              99.3%            98.6%                87.3%                 35.6%              -0.7%             1.4%                12.7%                 64.4%                   11.2%                    63.0%
#           vga_enh_top              5.00           MET         0.162               0.112             0.000                -1.230                -59.268              69.1%             0.0%              -759.3%             -36585.2%              30.9%           100.0%               859.3%              36685.2%                  759.3%                 36585.2%
#       risc16f84_clk2x              5.00           MET         1.262               1.260             1.259                 1.257                 -0.174              99.8%            99.8%                99.6%                -13.8%               0.2%             0.2%                 0.4%                113.8%                    0.2%                   113.5%
#           aes128_core             30.00           MET         5.475               5.468             5.333                 4.473                -13.398              99.9%            97.4%                81.7%               -244.7%               0.1%             2.6%                18.3%                344.7%                   15.7%                   342.1%
#             mrisc_top              5.00           MET         2.825               2.836             2.827                 2.810                  0.721              99.6%            99.9%                99.5%                 25.5%              -0.4%            -0.1%                 0.5%                 74.5%                    0.5%                    74.4%
#              aes_core             30.00           MET         8.644               8.592             8.552                 7.804                  4.514              99.4%            98.9%                90.3%                 52.2%               0.6%             1.1%                 9.7%                 47.8%                    8.7%                    46.7%
#          Sha3BlackBox              5.00           MET         0.400               0.461             0.347                 0.170                -12.189              84.8%            86.8%                42.5%              -3047.2%             -15.2%            13.3%                57.5%               3147.2%                   44.2%                  3134.0%
#                   fpu             30.00           MET         0.261               0.108            -0.443                -0.753                -70.343              41.4%          -169.7%              -288.5%             -26951.3%              58.6%           269.7%               388.5%              27051.3%                  118.8%                 26781.6%
#           RsEncodeTop              5.00           MET         1.987               2.035             1.962                 1.761                  0.509              97.6%            98.7%                88.6%                 25.6%              -2.4%             1.3%                11.4%                 74.4%                   10.1%                    73.1%
#                 sdram              2.50           MET         0.757               0.742             0.756                 0.778                  0.400              98.0%            99.9%                97.2%                 52.8%               2.0%             0.1%                -2.8%                 47.2%                    2.6%                    47.0%
# dynamic_node_top_wrap              5.00           MET         0.000               0.017            -0.034                 0.022                 -8.999               0.0%             0.0%                 0.0%                  0.0%            -100.0%          -100.0%              -100.0%               -100.0%                    0.0%                     0.0%
#           RsDecodeTop              5.00           MET         0.287               0.352             0.085                -2.585                -20.405              77.4%            29.6%              -900.7%              -7109.8%             -22.6%            70.4%              1000.7%               7209.8%                  930.3%                  7139.4%
#               picosoc              5.00           MET         0.042               0.070            -0.020                -1.323                -27.570              33.3%           -47.6%             -3150.0%             -65642.9%             -66.7%           147.6%              3250.0%              65742.9%                 3102.4%                 65595.2%
#             mips_core              5.00      VIOLATED        -0.027               0.011            -0.069                -0.086                 -8.427             -40.7%           -55.6%              -118.5%             -31011.1%            -140.7%           155.6%               218.5%              31111.1%                   63.0%                 30955.6%
#           pcm_slv_top              5.00           MET         1.394               1.387             1.385                 1.394                  1.343              99.5%            99.4%               100.0%                 96.3%               0.5%             0.6%                 0.0%                  3.7%                   -0.6%                     3.0%
#                  des3              5.00      VIOLATED        -3.748              -3.695            -3.717                -4.242                 -7.703              98.6%            99.2%                86.8%                 -5.5%              -1.4%            -0.8%                13.2%                105.5%                   12.4%                   104.7%
#                mc_top              5.00           MET         1.214               1.275             1.204                 0.995                 -4.251              95.0%            99.2%                82.0%               -350.2%              -5.0%             0.8%                18.0%                450.2%                   17.2%                   449.3%
#        aes_cipher_top              5.00           MET         1.948               1.993             1.961                 1.683                 -2.888              97.7%            99.3%                86.4%               -148.3%              -2.3%            -0.7%                13.6%                248.3%                   12.9%                   247.6%
#            wb_dma_top              5.00           MET         0.160               0.165             0.102                -0.026                 -2.689              96.9%            63.7%               -16.2%              -1680.6%              -3.1%            36.3%               116.2%               1780.6%                   80.0%                  1744.4%
#             plic_core              5.00           MET         1.856               1.883             1.841                 1.873                  0.053              98.5%            99.2%                99.1%                  2.9%              -1.5%             0.8%                -0.9%                 97.1%                    0.1%                    96.3%
#                sha256             30.00           MET        18.110              18.208            18.015                17.389                 13.440              99.5%            99.5%                96.0%                 74.2%              -0.5%             0.5%                 4.0%                 25.8%                    3.5%                    25.3%
#               dft_top              5.00      VIOLATED        -6.052              -5.865            -6.012               -17.697                -61.858              96.9%            99.3%               -92.4%               -822.1%              -3.1%            -0.7%               192.4%                922.1%                  191.8%                   921.4%
#                  MEAN              7.79             —         1.637               1.653             1.581                 0.829                -11.906              65.1%            38.6%              -155.6%             -10237.2%             -16.9%            54.6%               213.1%              10331.5%                  194.3%                 10275.9%

# %%
formatted_table_safe
# Out:
#                     Block Clock_Period (ns) Timing_Status WNS_Spef (ns)  \
# 0          simple_spi_top              5.00           MET         2.609
# 1            jpeg_encoder              5.00           MET         1.122
# 2              FIR_filter              5.00      VIOLATED        -0.009
# 3               rs_encode              5.00           MET         1.460
# 4                sasc_top              5.00           MET         2.587
# 5                 usb_phy              5.00           MET         2.878
# 6                 Network              5.00           MET         0.092
# 7     Top_PipelinedCipher              5.00           MET         0.590
# 8           wb_conmax_top              5.00           MET         0.105
# 9                ac97_top              5.00           MET         2.189
# 10             RocketTile              5.00           MET         2.278
# 11             psram_core              5.00           MET         1.089
# 12           pci_bridge32              5.00           MET         1.000
# 13                spi_top              5.00           MET         2.353
# 14            vga_enh_top              5.00           MET         0.162
# 15        risc16f84_clk2x              5.00           MET         1.262
# 16            aes128_core             30.00           MET         5.475
# 17              mrisc_top              5.00           MET         2.825
# 18               aes_core             30.00           MET         8.644
# 19           Sha3BlackBox              5.00           MET         0.400
# 20                    fpu             30.00           MET         0.261
# 21            RsEncodeTop              5.00           MET         1.987
# 22                  sdram              2.50           MET         0.757
# 23  dynamic_node_top_wrap              5.00           MET         0.000
# 24            RsDecodeTop              5.00           MET         0.287
# 25                picosoc              5.00           MET         0.042
# 26              mips_core              5.00      VIOLATED        -0.027
# 27            pcm_slv_top              5.00           MET         1.394
# 28                   des3              5.00      VIOLATED        -3.748
# 29                 mc_top              5.00           MET         1.214
# 30         aes_cipher_top              5.00           MET         1.948
# 31             wb_dma_top              5.00           MET         0.160
# 32              plic_core              5.00           MET         1.856
# 33                 sha256             30.00           MET        18.110
# 34                dft_top              5.00      VIOLATED        -6.052
# 35                   MEAN              7.79             —         1.637
#
#    WNS_EarlyRoute (ns) WNS_ML_Model (ns) WNS_Wireload_Fan (ns)  \
# 0                2.629             2.613                 2.651
# 1                1.149             1.083                -0.374
# 2                0.037            -0.098                 0.032
# 3                1.525             1.454                 1.300
# 4                2.566             2.569                 2.538
# 5                2.864             2.871                 2.851
# 6               -0.030            -0.029                -1.220
# 7                0.693             0.670                -1.968
# 8                0.013            -0.001                 0.291
# 9                2.220             2.195                 2.177
# 10               2.325             2.257                 2.056
# 11               1.088             1.088                 1.103
# 12               0.994             1.017                 1.052
# 13               2.370             2.319                 2.055
# 14               0.112             0.000                -1.230
# 15               1.260             1.259                 1.257
# 16               5.468             5.333                 4.473
# 17               2.836             2.827                 2.810
# 18               8.592             8.552                 7.804
# 19               0.461             0.347                 0.170
# 20               0.108            -0.443                -0.753
# 21               2.035             1.962                 1.761
# 22               0.742             0.756                 0.778
# 23               0.017            -0.034                 0.022
# 24               0.352             0.085                -2.585
# 25               0.070            -0.020                -1.323
# 26               0.011            -0.069                -0.086
# 27               1.387             1.385                 1.394
# 28              -3.695            -3.717                -4.242
# 29               1.275             1.204                 0.995
# 30               1.993             1.961                 1.683
# 31               0.165             0.102                -0.026
# 32               1.883             1.841                 1.873
# 33              18.208            18.015                17.389
# 34              -5.865            -6.012               -17.697
# 35               1.653             1.581                 0.829
#
#    WNS_Wireload_HPWL (ns) EarlyRoute_Acc (%) ML_Model_Acc (%)  \
# 0                   2.041              99.2%            99.8%
# 1                 -18.228              97.6%            96.5%
# 2                  -7.949            -411.1%          -888.9%
# 3                  -0.307              95.5%            99.6%
# 4                   1.627              99.2%            99.3%
# 5                   2.428              99.5%            99.8%
# 6                 -70.461             -32.6%           -31.5%
# 7                 -26.818              82.5%            86.4%
# 8                 -14.581              12.4%            -1.0%
# 9                  -0.050              98.6%            99.7%
# 10                 -2.177              97.9%            99.1%
# 11                  0.498              99.9%            99.9%
# 12                 -4.402              99.4%            98.3%
# 13                  0.837              99.3%            98.6%
# 14                -59.268              69.1%             0.0%
# 15                 -0.174              99.8%            99.8%
# 16                -13.398              99.9%            97.4%
# 17                  0.721              99.6%            99.9%
# 18                  4.514              99.4%            98.9%
# 19                -12.189              84.8%            86.8%
# 20                -70.343              41.4%          -169.7%
# 21                  0.509              97.6%            98.7%
# 22                  0.400              98.0%            99.9%
# 23                 -8.999               0.0%             0.0%
# 24                -20.405              77.4%            29.6%
# 25                -27.570              33.3%           -47.6%
# 26                 -8.427             -40.7%           -55.6%
# 27                  1.343              99.5%            99.4%
# 28                 -7.703              98.6%            99.2%
# 29                 -4.251              95.0%            99.2%
# 30                 -2.888              97.7%            99.3%
# 31                 -2.689              96.9%            63.7%
# 32                  0.053              98.5%            99.2%
# 33                 13.440              99.5%            99.5%
# 34                -61.858              96.9%            99.3%
# 35                -11.906              65.1%            38.6%
#
#    Wireload_Fan_Acc (%) Wireload_HPWL_Acc (%) EarlyRoute_Imp (%)  \
# 0                 98.4%                 78.2%              -0.8%
# 1                -33.3%              -1624.6%              -2.4%
# 2               -355.6%             -88122.2%            -511.1%
# 3                 89.0%                -21.0%              -4.5%
# 4                 98.1%                 62.9%               0.8%
# 5                 99.1%                 84.4%               0.5%
# 6              -1326.1%             -76588.0%             132.6%
# 7               -333.6%              -4545.4%             -17.5%
# 8                -77.1%             -13886.7%              87.6%
# 9                 99.5%                 -2.3%              -1.4%
# 10                90.3%                -95.6%              -2.1%
# 11                98.7%                 45.7%               0.1%
# 12                94.8%               -440.2%               0.6%
# 13                87.3%                 35.6%              -0.7%
# 14              -759.3%             -36585.2%              30.9%
# 15                99.6%                -13.8%               0.2%
# 16                81.7%               -244.7%               0.1%
# 17                99.5%                 25.5%              -0.4%
# 18                90.3%                 52.2%               0.6%
# 19                42.5%              -3047.2%             -15.2%
# 20              -288.5%             -26951.3%              58.6%
# 21                88.6%                 25.6%              -2.4%
# 22                97.2%                 52.8%               2.0%
# 23                 0.0%                  0.0%            -100.0%
# 24              -900.7%              -7109.8%             -22.6%
# 25             -3150.0%             -65642.9%             -66.7%
# 26              -118.5%             -31011.1%            -140.7%
# 27               100.0%                 96.3%               0.5%
# 28                86.8%                 -5.5%              -1.4%
# 29                82.0%               -350.2%              -5.0%
# 30                86.4%               -148.3%              -2.3%
# 31               -16.2%              -1680.6%              -3.1%
# 32                99.1%                  2.9%              -1.5%
# 33                96.0%                 74.2%              -0.5%
# 34               -92.4%               -822.1%              -3.1%
# 35              -155.6%             -10237.2%             -16.9%
#
#    ML_Model_Imp (%) Wireload_Fan_Imp (%) Wireload_HPWL_Imp (%)  \
# 0             -0.2%                -1.6%                 21.8%
# 1              3.5%               133.3%               1724.6%
# 2            988.9%              -455.6%              88222.2%
# 3              0.4%                11.0%                121.0%
# 4              0.7%                 1.9%                 37.1%
# 5              0.2%                 0.9%                 15.6%
# 6            131.5%              1426.1%              76688.0%
# 7            -13.6%               433.6%               4645.4%
# 8            101.0%              -177.1%              13986.7%
# 9             -0.3%                 0.5%                102.3%
# 10             0.9%                 9.7%                195.6%
# 11             0.1%                -1.3%                 54.3%
# 12            -1.7%                -5.2%                540.2%
# 13             1.4%                12.7%                 64.4%
# 14           100.0%               859.3%              36685.2%
# 15             0.2%                 0.4%                113.8%
# 16             2.6%                18.3%                344.7%
# 17            -0.1%                 0.5%                 74.5%
# 18             1.1%                 9.7%                 47.8%
# 19            13.3%                57.5%               3147.2%
# 20           269.7%               388.5%              27051.3%
# 21             1.3%                11.4%                 74.4%
# 22             0.1%                -2.8%                 47.2%
# 23          -100.0%              -100.0%               -100.0%
# 24            70.4%              1000.7%               7209.8%
# 25           147.6%              3250.0%              65742.9%
# 26           155.6%               218.5%              31111.1%
# 27             0.6%                 0.0%                  3.7%
# 28            -0.8%                13.2%                105.5%
# 29             0.8%                18.0%                450.2%
# 30            -0.7%                13.6%                248.3%
# 31            36.3%               116.2%               1780.6%
# 32             0.8%                -0.9%                 97.1%
# 33             0.5%                 4.0%                 25.8%
# 34            -0.7%               192.4%                922.1%
# 35            54.6%               213.1%              10331.5%
#
#    ML_vs_Best_Wireload (%) ML_vs_Worst_Wireload (%)
# 0                     1.5%                    21.6%
# 1                   129.9%                  1721.1%
# 2                  -533.3%                 87233.3%
# 3                    10.5%                   120.6%
# 4                     1.2%                    36.4%
# 5                     0.7%                    15.4%
# 6                  1294.6%                 76556.5%
# 7                   420.0%                  4631.9%
# 8                    76.2%                 13885.7%
# 9                     0.3%                   102.0%
# 10                    8.8%                   194.6%
# 11                    1.2%                    54.2%
# 12                    3.5%                   538.5%
# 13                   11.2%                    63.0%
# 14                  759.3%                 36585.2%
# 15                    0.2%                   113.5%
# 16                   15.7%                   342.1%
# 17                    0.5%                    74.4%
# 18                    8.7%                    46.7%
# 19                   44.2%                  3134.0%
# 20                  118.8%                 26781.6%
# 21                   10.1%                    73.1%
# 22                    2.6%                    47.0%
# 23                    0.0%                     0.0%
# 24                  930.3%                  7139.4%
# 25                 3102.4%                 65595.2%
# 26                   63.0%                 30955.6%
# 27                   -0.6%                     3.0%
# 28                   12.4%                   104.7%
# 29                   17.2%                   449.3%
# 30                   12.9%                   247.6%
# 31                   80.0%                  1744.4%
# 32                    0.1%                    96.3%
# 33                    3.5%                    25.3%
# 34                  191.8%                   921.4%
# 35                  194.3%                 10275.9%

# %%
df
# Out:
#                     block  wns_spef  wns_early_route  wns_model_predicted  \
# 0          simple_spi_top     2.609            2.629                2.613
# 1            jpeg_encoder     1.122            1.149                1.083
# 2              FIR_filter    -0.009            0.037               -0.098
# 3               rs_encode     1.460            1.525                1.454
# 4                sasc_top     2.587            2.566                2.569
# 5                 usb_phy     2.878            2.864                2.871
# 6                 Network     0.092           -0.030               -0.029
# 7     Top_PipelinedCipher     0.590            0.693                0.670
# 8           wb_conmax_top     0.105            0.013               -0.001
# 9                ac97_top     2.189            2.220                2.195
# 10             RocketTile     2.278            2.325                2.257
# 11             psram_core     1.089            1.088                1.088
# 12           pci_bridge32     1.000            0.994                1.017
# 13                spi_top     2.353            2.370                2.319
# 14            vga_enh_top     0.162            0.112                0.000
# 15        risc16f84_clk2x     1.262            1.260                1.259
# 16            aes128_core     5.475            5.468                5.333
# 17              mrisc_top     2.825            2.836                2.827
# 18               aes_core     8.644            8.592                8.552
# 19           Sha3BlackBox     0.400            0.461                0.347
# 20                    fpu     0.261            0.108               -0.443
# 21            RsEncodeTop     1.987            2.035                1.962
# 22                  sdram     0.757            0.742                0.756
# 23  dynamic_node_top_wrap     0.000            0.017               -0.034
# 24            RsDecodeTop     0.287            0.352                0.085
# 25                picosoc     0.042            0.070               -0.020
# 26              mips_core    -0.027            0.011               -0.069
# 27            pcm_slv_top     1.394            1.387                1.385
# 28                   des3    -3.748           -3.695               -3.717
# 29                 mc_top     1.214            1.275                1.204
# 30         aes_cipher_top     1.948            1.993                1.961
# 31             wb_dma_top     0.160            0.165                0.102
# 32              plic_core     1.856            1.883                1.841
# 33                 sha256    18.110           18.208               18.015
# 34                dft_top    -6.052           -5.865               -6.012
#
#     wns_wireload_fan  wns_wireload_hpwl  clock_period
# 0              2.651              2.041           5.0
# 1             -0.374            -18.228           5.0
# 2              0.032             -7.949           5.0
# 3              1.300             -0.307           5.0
# 4              2.538              1.627           5.0
# 5              2.851              2.428           5.0
# 6             -1.220            -70.461           5.0
# 7             -1.968            -26.818           5.0
# 8              0.291            -14.581           5.0
# 9              2.177             -0.050           5.0
# 10             2.056             -2.177           5.0
# 11             1.103              0.498           5.0
# 12             1.052             -4.402           5.0
# 13             2.055              0.837           5.0
# 14            -1.230            -59.268           5.0
# 15             1.257             -0.174           5.0
# 16             4.473            -13.398          30.0
# 17             2.810              0.721           5.0
# 18             7.804              4.514          30.0
# 19             0.170            -12.189           5.0
# 20            -0.753            -70.343          30.0
# 21             1.761              0.509           5.0
# 22             0.778              0.400           2.5
# 23             0.022             -8.999           5.0
# 24            -2.585            -20.405           5.0
# 25            -1.323            -27.570           5.0
# 26            -0.086             -8.427           5.0
# 27             1.394              1.343           5.0
# 28            -4.242             -7.703           5.0
# 29             0.995             -4.251           5.0
# 30             1.683             -2.888           5.0
# 31            -0.026             -2.689           5.0
# 32             1.873              0.053           5.0
# 33            17.389             13.440          30.0
# 34           -17.697            -61.858           5.0

# %%
mean_absolute_error(y_real, y_model_predicted)
mean_absolute_percentage_error(y_real, y_model_predicted)
# Out:
# 2830834051492.5537

# %%
#df
def safe_regression_metrics(y_true, y_pred, epsilon=1e-8):
    """
    Безопасные метрики для регрессии с нулевыми значениями
    """
    # Убедимся, что массивы numpy
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    metrics = {}
    
    # 1. Mean Squared Error (MSE) - безопасен с нулями
    metrics['mse'] = mean_squared_error(y_true, y_pred)
    metrics['rmse'] = np.sqrt(metrics['mse'])
    
    # 2. Mean Absolute Error (MAE) - безопасен с нулями
    metrics['mae'] = mean_absolute_error(y_true, y_pred)
    
    # 3. R² Score - безопасен с нулями
    metrics['r2'] = r2_score(y_true, y_pred)
    
    # 4. Mean Absolute Percentage Error (MAPE) с защитой от деления на ноль
    mask = y_true != 0  # Игнорируем случаи где y_true = 0
    if np.sum(mask) > 0:  # Если есть ненулевые значения
        mape = np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100
        metrics['mape'] = mape
        metrics['mape_non_zero_samples'] = np.sum(mask)
    else:
        metrics['mape'] = None
        metrics['mape_non_zero_samples'] = 0
    
    # 5. Symmetric Mean Absolute Percentage Error (sMAPE) - более устойчивый
    denominator = np.abs(y_true) + np.abs(y_pred) + epsilon
    smape = np.mean(2.0 * np.abs(y_pred - y_true) / denominator) * 100
    metrics['smape'] = smape
    
    # 6. Mean Absolute Scaled Error (MASE) - альтернатива MAPE
    naive_forecast = np.roll(y_true, 1)
    naive_mae = mean_absolute_error(y_true[1:], naive_forecast[1:])
    if naive_mae > 0:
        metrics['mase'] = metrics['mae'] / naive_mae
    else:
        metrics['mase'] = None
    
    # 7. Корреляции (безопасны с нулями)
    metrics['pearson_corr'] = np.corrcoef(y_true, y_pred)[0, 1]
    metrics['spearman_corr'] = pd.Series(y_true).corr(pd.Series(y_pred), method='spearman')
    
    return metrics

# %%
safe_regression_metrics(y_real, y_model_predicted)
# Out:
# {'mse': 4.6322658571428565,
#  'rmse': np.float64(2.1522699312918108),
#  'mae': 0.8308285714285714,
#  'r2': 0.6459225386860603,
#  'mape': np.float64(260.19070658870913),
#  'mape_non_zero_samples': np.int64(34),
#  'smape': np.float64(72.04821695724189),
#  'mase': 0.2856033589995796,
#  'pearson_corr': np.float64(0.9161500907178836),
#  'spearman_corr': np.float64(0.9229691876750701)}

# %%
df
# Out:
#                     block  wns_spef  wns_early_route  wns_model_predicted  \
# 0          simple_spi_top     2.609            2.629                2.613
# 1            jpeg_encoder     1.122            1.149                1.083
# 2              FIR_filter    -0.009            0.037               -0.098
# 3               rs_encode     1.460            1.525                1.454
# 4                sasc_top     2.587            2.566                2.569
# 5                 usb_phy     2.878            2.864                2.871
# 6                 Network     0.092           -0.030               -0.029
# 7     Top_PipelinedCipher     0.590            0.693                0.670
# 8           wb_conmax_top     0.105            0.013               -0.001
# 9                ac97_top     2.189            2.220                2.195
# 10             RocketTile     2.278            2.325                2.257
# 11             psram_core     1.089            1.088                1.088
# 12           pci_bridge32     1.000            0.994                1.017
# 13                spi_top     2.353            2.370                2.319
# 14            vga_enh_top     0.162            0.112                0.000
# 15        risc16f84_clk2x     1.262            1.260                1.259
# 16            aes128_core     5.475            5.468                5.333
# 17              mrisc_top     2.825            2.836                2.827
# 18               aes_core     8.644            8.592                8.552
# 19           Sha3BlackBox     0.400            0.461                0.347
# 20                    fpu     0.261            0.108               -0.443
# 21            RsEncodeTop     1.987            2.035                1.962
# 22                  sdram     0.757            0.742                0.756
# 23  dynamic_node_top_wrap     0.000            0.017               -0.034
# 24            RsDecodeTop     0.287            0.352                0.085
# 25                picosoc     0.042            0.070               -0.020
# 26              mips_core    -0.027            0.011               -0.069
# 27            pcm_slv_top     1.394            1.387                1.385
# 28                   des3    -3.748           -3.695               -3.717
# 29                 mc_top     1.214            1.275                1.204
# 30         aes_cipher_top     1.948            1.993                1.961
# 31             wb_dma_top     0.160            0.165                0.102
# 32              plic_core     1.856            1.883                1.841
# 33                 sha256    18.110           18.208               18.015
# 34                dft_top    -6.052           -5.865               -6.012
#
#     wns_wireload_fan  wns_wireload_hpwl  clock_period
# 0              2.651              2.041           5.0
# 1             -0.374            -18.228           5.0
# 2              0.032             -7.949           5.0
# 3              1.300             -0.307           5.0
# 4              2.538              1.627           5.0
# 5              2.851              2.428           5.0
# 6             -1.220            -70.461           5.0
# 7             -1.968            -26.818           5.0
# 8              0.291            -14.581           5.0
# 9              2.177             -0.050           5.0
# 10             2.056             -2.177           5.0
# 11             1.103              0.498           5.0
# 12             1.052             -4.402           5.0
# 13             2.055              0.837           5.0
# 14            -1.230            -59.268           5.0
# 15             1.257             -0.174           5.0
# 16             4.473            -13.398          30.0
# 17             2.810              0.721           5.0
# 18             7.804              4.514          30.0
# 19             0.170            -12.189           5.0
# 20            -0.753            -70.343          30.0
# 21             1.761              0.509           5.0
# 22             0.778              0.400           2.5
# 23             0.022             -8.999           5.0
# 24            -2.585            -20.405           5.0
# 25            -1.323            -27.570           5.0
# 26            -0.086             -8.427           5.0
# 27             1.394              1.343           5.0
# 28            -4.242             -7.703           5.0
# 29             0.995             -4.251           5.0
# 30             1.683             -2.888           5.0
# 31            -0.026             -2.689           5.0
# 32             1.873              0.053           5.0
# 33            17.389             13.440          30.0
# 34           -17.697            -61.858           5.0

# %%
model.predict
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from catboost import CatBoostRegressor
from sklearn.preprocessing import StandardScaler

# get blocks
dataset_path = './dataset/'
items = os.listdir(dataset_path)
blocks = [item for item in items if os.path.isdir(os.path.join(dataset_path, item))]

df_blocks_list = []
block_names = []

for block in blocks:
    # get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/net_feat.csv", sep=';')

    # drop all nets with zero capacitence
    df = df[df['cap'] != 0]
    df = df[df['pin_cap'] != 0]

    # drop all Nan rows
    df = df.dropna()

    # drop net name column
    df = df.drop(columns=['net'], axis=1)
    
    # Add block identifier
    df['block_id'] = block
    
    # append df to common df
    df_blocks_list.append(df)
    block_names.append(block)

# create common df
df = pd.concat(df_blocks_list, ignore_index=True)

# transfer capacintece from pF to fF
df['cap'] = df['cap'] * 1000
df['pin_cap'] = df['pin_cap'] * 1000
df['wireload_fan_cap'] = df['wireload_fan_cap'] * 1000
df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] * 1000

# add block area feature
df['block_area'] = df['block_width'] * df['block_height']

# add area feature
df['gcell_area'] = (df['urx'] - df['llx']) * (df['ury'] - df['lly'])

# add aspect ration feat
df['gcell_ar'] = (df['urx'] - df['llx']) / (df['ury'] - df['lly'])

df['abs_x'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']
df['abs_y'] = (((df['ury'] - df['lly']) / 2) + df['lly']) / df['block_height']

df['dist_to_right'] = ((df['block_width'] - ((df['urx'] - df['llx']) / 2) + df['llx'])) / df['block_width']
df['dist_to_left'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']

df['dist_to_top'] = (df['block_height'] - (((df['ury'] - df['lly']) / 2) + df['lly'])) / df['block_height']
df['dist_to_bottom'] = ((((df['ury'] - df['lly']) / 2) + df['lly']))

# ration wire cap / pin cap
# df ['wire_to_pin_cap_ratio'] = df['cap'] / df['pin_cap'] 

# drop metal segs
df = df.drop(columns=['m2_segs', 'm3_segs', 'm4_segs', 'm5_segs', 'm6_segs', 'm7_segs'])

# drop all labels except cap
df = df.drop(columns=['length', 'vias', 'segs'])

# Определяем фичи и таргет
#features = [col for col in df.columns if col not in ['cap', 'block_id']]
features = ['fanin', 'fanout', 'fanin_area', 'fanout_area', 'hpwl', 'hpwl_min', 'hpwl_max', 'hpwl_mean', 'hpwl_stddev', 'cell_density', 'pin_cap', 'wireload_fan_cap', 'wireload_hpwl_cap', 'gcell_area', 'gcell_ar']
X = df[features]
y = df['cap']
groups = df['block_id']

# Проверяем количество уникальных блоков
unique_blocks = df['block_id'].unique()
print(f"Всего уникальных блоков: {len(unique_blocks)}")

# Создаем кастомную стратегию для 7 фолдов (30 train / 5 test)
n_splits = 7
n_blocks_total = len(unique_blocks)
n_test_blocks = 5
n_train_blocks = n_blocks_total - n_test_blocks

print(f"Всего блоков: {n_blocks_total}")
print(f"Количество фолдов: {n_splits}")
print(f"Блоков в обучении на фолд: {n_train_blocks}")
print(f"Блоков в тесте на фолд: {n_test_blocks}")

# Случайно перемешиваем блоки для разнообразия фолдов
np.random.seed(42)
shuffled_blocks = np.random.permutation(unique_blocks)

# Метрики для хранения результатов
mse_scores = []
mae_scores = []
mape_scores = []
r2_scores = []
feature_importances = []

# Кастомная кросс-валидация по блокам
for fold in range(n_splits):
    print(f"\n--- Фолд {fold + 1} ---")
    
    # Вычисляем индексы для тестовых блоков (скользящее окно)
    start_idx = fold * n_test_blocks
    end_idx = start_idx + n_test_blocks
    
    # Если вышли за границы, начинаем сначала
    if end_idx > n_blocks_total:
        start_idx = 0
        end_idx = n_test_blocks
    
    test_blocks = shuffled_blocks[start_idx:end_idx]
    train_blocks = np.array([block for block in shuffled_blocks if block not in test_blocks])
    
    print(f"Тренировочные блоки ({len(train_blocks)}): {train_blocks}")
    print(f"Тестовые блоки ({len(test_blocks)}): {test_blocks}")
    
    # Создаем маски для train/test
    train_mask = df['block_id'].isin(train_blocks)
    test_mask = df['block_id'].isin(test_blocks)
    
    X_train, X_test = X[train_mask], X[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]
    
    print(f"Тренировочные samples: {len(X_train)}")
    print(f"Тестовые samples: {len(X_test)}")
    
    # Масштабирование фичей (CatBoost обычно не требует масштабирования, но оставим для консистентности)
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Обучаем CatBoost
    model = CatBoostRegressor(
        iterations=100,
        depth=10,
        learning_rate=0.1,
        random_seed=42,
        verbose=False,  # Отключаем вывод обучения
        loss_function='RMSE'
    )
    
    model.fit(X_train_scaled, y_train)
    
    # Предсказания
    y_pred = model.predict(X_test_scaled)
    
    # Вычисляем метрики
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    mse_scores.append(mse)
    mae_scores.append(mae)
    mape_scores.append(mape)
    r2_scores.append(r2)
    
    # Сохраняем важность фичей
    feature_importances.append(model.get_feature_importance())
    
    print(f"MSE: {mse:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"MAPE: {mape:.4f}")
    print(f"R²: {r2:.4f}")

# Выводим итоговые результаты
print("\n" + "="*50)
print("ИТОГИ КРОСС-ВАЛИДАЦИИ")
print("="*50)
print(f"Среднее MSE: {np.mean(mse_scores):.4f} (±{np.std(mse_scores):.4f})")
print(f"Среднее MAE: {np.mean(mae_scores):.4f} (±{np.std(mae_scores):.4f})")
print(f"Среднее MAPE: {np.mean(mape_scores):.4f} (±{np.std(mape_scores):.4f})")
print(f"Среднее R²: {np.mean(r2_scores):.4f} (±{np.std(r2_scores):.4f})")

# Анализ важности фичей
avg_feature_importance = np.mean(feature_importances, axis=0)
feature_importance_df = pd.DataFrame({
    'feature': features,
    'importance': avg_feature_importance
}).sort_values('importance', ascending=False)

print("\nВажность фичей (средняя по фолдам):")
print(feature_importance_df)

# Визуализация важности фичей (опционально)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['feature'], feature_importance_df['importance'])
plt.xlabel('Важность')
plt.title('Средняя важность фичей по фолдам (CatBoost)')
plt.tight_layout()
plt.show()

# Обучение финальной модели на всех данных (опционально)
print("\nОбучение финальной модели на всех данных...")
final_scaler = StandardScaler()
X_scaled = final_scaler.fit_transform(X)

final_model = CatBoostRegressor(
    iterations=100,
    depth=6,
    learning_rate=0.1,
    random_seed=42,
    verbose=False,
    loss_function='RMSE'
)
final_model.fit(X_scaled, y)

print("Финальная модель CatBoost обучена!")

# Дополнительно: можно сохранить модель
# final_model.save_model('catboost_cap_predictor.cbm')
# Out:
# Всего уникальных блоков: 35
# Всего блоков: 35
# Количество фолдов: 7
# Блоков в обучении на фолд: 30
# Блоков в тесте на фолд: 5
#
# --- Фолд 1 ---
# Тренировочные блоки (30): ['mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x']
# Тренировочные samples: 537593
# Тестовые samples: 27305
# MSE: 1.4535
# MAE: 0.4770
# MAPE: 0.1297
# R²: 0.9647
#
# --- Фолд 2 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core']
# Тренировочные samples: 514061
# Тестовые samples: 50837
# MSE: 20.1448
# MAE: 1.2931
# MAPE: 0.1526
# R²: 0.8479
#
# --- Фолд 3 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'pcm_slv_top' 'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter'
#  'plic_core' 'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap'
#  'wb_dma_top' 'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu'
#  'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top']
# Тренировочные samples: 556035
# Тестовые samples: 8863
# MSE: 0.9569
# MAE: 0.4541
# MAPE: 0.1147
# R²: 0.9679
#
# --- Фолд 4 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['pcm_slv_top' 'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter']
# Тренировочные samples: 541474
# Тестовые samples: 23424
# MSE: 0.6809
# MAE: 0.3629
# MAPE: 0.1666
# R²: 0.9649
#
# --- Фолд 5 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'RocketTile' 'sdram'
#  'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top' 'Top_PipelinedCipher'
#  'vga_enh_top' 'des3']
# Тестовые блоки (5): ['plic_core' 'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap'
#  'wb_dma_top']
# Тренировочные samples: 547156
# Тестовые samples: 17742
# MSE: 1.0816
# MAE: 0.5094
# MAPE: 0.1231
# R²: 0.9653
#
# --- Фолд 6 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top' 'fpu'
#  'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network']
# Тренировочные samples: 314309
# Тестовые samples: 250589
# MSE: 12.6258
# MAE: 0.7894
# MAPE: 0.1020
# R²: 0.8920
#
# --- Фолд 7 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network']
# Тестовые блоки (5): ['fpu' 'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тренировочные samples: 378760
# Тестовые samples: 186138
# MSE: 2.9173
# MAE: 0.5347
# MAPE: 0.1054
# R²: 0.9403
#
# ==================================================
# ИТОГИ КРОСС-ВАЛИДАЦИИ
# ==================================================
# Среднее MSE: 5.6944 (±7.0853)
# Среднее MAE: 0.6315 (±0.2963)
# Среднее MAPE: 0.1277 (±0.0223)
# Среднее R²: 0.9347 (±0.0435)
#
# Важность фичей (средняя по фолдам):
#               feature  importance
# 4                hpwl   46.136358
# 3         fanout_area   12.343543
# 1              fanout    8.612973
# 6            hpwl_max    6.866643
# 11   wireload_fan_cap    6.580920
# 12  wireload_hpwl_cap    5.018583
# 10            pin_cap    3.202138
# 9        cell_density    2.471800
# 2          fanin_area    2.267856
# 7           hpwl_mean    2.105321
# 14           gcell_ar    1.580400
# 8         hpwl_stddev    0.947990
# 5            hpwl_min    0.842001
# 0               fanin    0.690014
# 13         gcell_area    0.333461
# Обучение финальной модели на всех данных...
# Финальная модель CatBoost обучена!

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.multioutput import MultiOutputRegressor

# get blocks
dataset_path = './dataset/'
items = os.listdir(dataset_path)
blocks = [item for item in items if os.path.isdir(os.path.join(dataset_path, item))]

df_blocks_list = []
block_names = []

for block in blocks:
    # get net_feat.csv (feate store and labels)
    df = pd.read_csv(f"./{dataset_path}/{block}/net_feat.csv", sep=';')

    # drop all nets with zero capacitence
    df = df[df['cap'] != 0]
    df = df[df['pin_cap'] != 0]

    # drop all Nan rows
    df = df.dropna()

    # drop net name column
    df = df.drop(columns=['net'], axis=1)
    
    # Add block identifier
    df['block_id'] = block
    
    # append df to common df
    df_blocks_list.append(df)
    block_names.append(block)

# create common df
df = pd.concat(df_blocks_list, ignore_index=True)

# transfer capacintece from pF to fF
df['cap'] = df['cap'] * 1000
df['pin_cap'] = df['pin_cap'] * 1000
df['wireload_fan_cap'] = df['wireload_fan_cap'] * 1000
df['wireload_hpwl_cap'] = df['wireload_hpwl_cap'] * 1000

# add block area feature
df['block_area'] = df['block_width'] * df['block_height']

# add area feature
df['gcell_area'] = (df['urx'] - df['llx']) * (df['ury'] - df['lly'])

# add aspect ration feat
df['gcell_ar'] = (df['urx'] - df['llx']) / (df['ury'] - df['lly'])

df['abs_x'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']
df['abs_y'] = (((df['ury'] - df['lly']) / 2) + df['lly']) / df['block_height']

df['dist_to_right'] = ((df['block_width'] - ((df['urx'] - df['llx']) / 2) + df['llx'])) / df['block_width']
df['dist_to_left'] = (((df['urx'] - df['llx']) / 2) + df['llx']) / df['block_width']

df['dist_to_top'] = (df['block_height'] - (((df['ury'] - df['lly']) / 2) + df['lly'])) / df['block_height']
df['dist_to_bottom'] = ((((df['ury'] - df['lly']) / 2) + df['lly']))

# НЕ удаляем таргеты для многозадачной регрессии
# Вместо этого определяем multiple targets
targets = ['cap', 'length', 'segs']  # Добавляем все нужные таргеты

# Определяем фичи
features = ['fanin', 'fanout', 'fanin_area', 'hpwl', 'hpwl_min', 'hpwl_stddev', 'cell_density', 'pin_cap', 'gcell_area', 'gcell_ar']

X = df[features]
y = df[targets]  # Множественные таргеты
groups = df['block_id']

# Проверяем количество уникальных блоков
unique_blocks = df['block_id'].unique()
print(f"Всего уникальных блоков: {len(unique_blocks)}")

# Создаем кастомную стратегию для 7 фолдов (30 train / 5 test)
n_splits = 7
n_blocks_total = len(unique_blocks)
n_test_blocks = 5
n_train_blocks = n_blocks_total - n_test_blocks

print(f"Всего блоков: {n_blocks_total}")
print(f"Количество фолдов: {n_splits}")
print(f"Блоков в обучении на фолд: {n_train_blocks}")
print(f"Блоков в тесте на фолд: {n_test_blocks}")

# Случайно перемешиваем блоки для разнообразия фолдов
np.random.seed(42)
shuffled_blocks = np.random.permutation(unique_blocks)

# Метрики для хранения результатов (теперь для каждого таргета отдельно)
metrics_per_target = {
    'cap': {'mse': [], 'mae': [], 'mape': [], 'r2': []},
    'length': {'mse': [], 'mae': [], 'mape': [], 'r2': []},
    'segs': {'mse': [], 'mae': [], 'mape': [], 'r2': []}
}

feature_importances = []

# Кастомная кросс-валидация по блокам
for fold in range(n_splits):
    print(f"\n--- Фолд {fold + 1} ---")
    
    # Вычисляем индексы для тестовых блоков (скользящее окно)
    start_idx = fold * n_test_blocks
    end_idx = start_idx + n_test_blocks
    
    # Если вышли за границы, начинаем сначала
    if end_idx > n_blocks_total:
        start_idx = 0
        end_idx = n_test_blocks
    
    test_blocks = shuffled_blocks[start_idx:end_idx]
    train_blocks = np.array([block for block in shuffled_blocks if block not in test_blocks])
    
    print(f"Тренировочные блоки ({len(train_blocks)}): {train_blocks}")
    print(f"Тестовые блоки ({len(test_blocks)}): {test_blocks}")
    
    # Создаем маски для train/test
    train_mask = df['block_id'].isin(train_blocks)
    test_mask = df['block_id'].isin(test_blocks)
    
    X_train, X_test = X[train_mask], X[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]
    
    print(f"Тренировочные samples: {len(X_train)}")
    print(f"Тестовые samples: {len(X_test)}")
    
    # Масштабирование фичей
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Вариант 1: MultiOutputRegressor с XGBoost (рекомендуется)
    print("Обучение MultiOutput XGBoost...")
    xgb_model = xgb.XGBRegressor(
        n_estimators=100,
        max_depth=10,
        learning_rate=0.1,
        random_state=42,
        verbosity=0
    )
    
    multi_model = MultiOutputRegressor(xgb_model)
    multi_model.fit(X_train_scaled, y_train)
    
    # Предсказания для всех таргетов
    y_pred = multi_model.predict(X_test_scaled)
    
    # Вычисляем метрики для каждого таргета
    for i, target in enumerate(targets):
        y_true_single = y_test[target].values
        y_pred_single = y_pred[:, i]
        
        mse = mean_squared_error(y_true_single, y_pred_single)
        mae = mean_absolute_error(y_true_single, y_pred_single)
        mape = mean_absolute_percentage_error(y_true_single, y_pred_single)
        r2 = r2_score(y_true_single, y_pred_single)
        
        metrics_per_target[target]['mse'].append(mse)
        metrics_per_target[target]['mae'].append(mae)
        metrics_per_target[target]['mape'].append(mape)
        metrics_per_target[target]['r2'].append(r2)
        
        print(f"{target.upper()} - MSE: {mse:.4f}, MAE: {mae:.4f}, MAPE: {mape:.4f}, R²: {r2:.4f}")
    
    # Сохраняем важность фичей (берем от первого estimator'а)
    feature_importances.append(multi_model.estimators_[0].get_booster().get_score(importance_type='weight'))

# Выводим итоговые результаты для каждого таргета
print("\n" + "="*60)
print("ИТОГИ КРОСС-ВАЛИДАЦИИ - МНОГОЗАДАЧНАЯ РЕГРЕССИЯ")
print("="*60)

for target in targets:
    print(f"\n📊 {target.upper()} - Средние метрики по всем фолдам:")
    print(f"  MSE:  {np.mean(metrics_per_target[target]['mse']):.4f} (±{np.std(metrics_per_target[target]['mse']):.4f})")
    print(f"  MAE:  {np.mean(metrics_per_target[target]['mae']):.4f} (±{np.std(metrics_per_target[target]['mae']):.4f})")
    print(f"  MAPE: {np.mean(metrics_per_target[target]['mape']):.4f} (±{np.std(metrics_per_target[target]['mape']):.4f})")
    print(f"  R²:   {np.mean(metrics_per_target[target]['r2']):.4f} (±{np.std(metrics_per_target[target]['r2']):.4f})")

# Альтернативный вариант: отдельные модели для каждого таргета
print("\n" + "="*50)
print("АЛЬТЕРНАТИВА: ОТДЕЛЬНЫЕ МОДЕЛИ ДЛЯ КАЖДОГО ТАРГЕТА")
print("="*50)

# Метрики для отдельных моделей
individual_metrics = {target: {'mse': [], 'mae': [], 'mape': [], 'r2': []} for target in targets}

for fold in range(n_splits):
    print(f"\n--- Фолд {fold + 1} (Отдельные модели) ---")
    
    # Те же самые сплиты
    start_idx = fold * n_test_blocks
    end_idx = start_idx + n_test_blocks
    if end_idx > n_blocks_total:
        start_idx = 0
        end_idx = n_test_blocks
    
    test_blocks = shuffled_blocks[start_idx:end_idx]
    train_blocks = np.array([block for block in shuffled_blocks if block not in test_blocks])
    
    train_mask = df['block_id'].isin(train_blocks)
    test_mask = df['block_id'].isin(test_blocks)
    
    X_train, X_test = X[train_mask], X[test_mask]
    y_train, y_test = y[train_mask], y[test_mask]
    
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Обучаем отдельную модель для каждого таргета
    individual_models = {}
    for target in targets:
        print(f"Обучение XGBoost для {target}...")
        
        model = xgb.XGBRegressor(
            n_estimators=100,
            max_depth=10,
            learning_rate=0.1,
            random_state=42,
            verbosity=0
        )
        
        model.fit(X_train_scaled, y_train[target])
        individual_models[target] = model
        
        # Предсказания и метрики
        y_pred = model.predict(X_test_scaled)
        
        mse = mean_squared_error(y_test[target], y_pred)
        mae = mean_absolute_error(y_test[target], y_pred)
        mape = mean_absolute_percentage_error(y_test[target], y_pred)
        r2 = r2_score(y_test[target], y_pred)
        
        individual_metrics[target]['mse'].append(mse)
        individual_metrics[target]['mae'].append(mae)
        individual_metrics[target]['mape'].append(mape)
        individual_metrics[target]['r2'].append(r2)
        
        print(f"  {target.upper()} - MSE: {mse:.4f}, R²: {r2:.4f}")

# Сравнение результатов
print("\n" + "="*60)
print("СРАВНЕНИЕ ПОДХОДОВ")
print("="*60)

for target in targets:
    print(f"\n🎯 {target.upper()}:")
    print(f"  MultiOutput R²: {np.mean(metrics_per_target[target]['r2']):.4f}")
    print(f"  Individual R²:  {np.mean(individual_metrics[target]['r2']):.4f}")

# Обучение финальных моделей на всех данных
print("\nОбучение финальных моделей на всех данных...")
final_scaler = StandardScaler()
X_scaled = final_scaler.fit_transform(X)

# Вариант 1: Финальная MultiOutput модель
final_multi_model = MultiOutputRegressor(
    xgb.XGBRegressor(
        n_estimators=100,
        max_depth=10,
        learning_rate=0.1,
        random_state=42,
        verbosity=0
    )
)
final_multi_model.fit(X_scaled, y)
print("✅ Финальная MultiOutput модель обучена!")

# Вариант 2: Финальные отдельные модели
final_individual_models = {}
for target in targets:
    model = xgb.XGBRegressor(
        n_estimators=100,
        max_depth=10,
        learning_rate=0.1,
        random_state=42,
        verbosity=0
    )
    model.fit(X_scaled, y[target])
    final_individual_models[target] = model
    print(f"✅ Финальная модель для {target} обучена!")

# Сохранение моделей (опционально)
# import joblib
# joblib.dump(final_multi_model, 'xgb_multioutput_model.pkl')
# joblib.dump(final_individual_models, 'xgb_individual_models.pkl')
# joblib.dump(final_scaler, 'scaler.pkl')

print("\n🎯 Все модели успешно обучены!")
# Out:
# Всего уникальных блоков: 35
# Всего блоков: 35
# Количество фолдов: 7
# Блоков в обучении на фолд: 30
# Блоков в тесте на фолд: 5
#
# --- Фолд 1 ---
# Тренировочные блоки (30): ['mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x']
# Тренировочные samples: 537593
# Тестовые samples: 27305
# Обучение MultiOutput XGBoost...
# CAP - MSE: 1.5050, MAE: 0.4399, MAPE: 0.1016, R²: 0.9634
# LENGTH - MSE: 62.1701, MAE: 2.6356, MAPE: 0.1309, R²: 0.9751
# SEGS - MSE: 36.6286, MAE: 3.5313, MAPE: 0.3368, R²: 0.9654
#
# --- Фолд 2 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core']
# Тренировочные samples: 514061
# Тестовые samples: 50837
# Обучение MultiOutput XGBoost...
# CAP - MSE: 17.3163, MAE: 1.1523, MAPE: 0.1414, R²: 0.8693
# LENGTH - MSE: 488.8016, MAE: 4.3751, MAPE: 0.1529, R²: 0.9153
# SEGS - MSE: 144.0474, MAE: 5.2568, MAPE: 0.3232, R²: 0.8855
#
# --- Фолд 3 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'pcm_slv_top' 'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter'
#  'plic_core' 'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap'
#  'wb_dma_top' 'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu'
#  'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top']
# Тренировочные samples: 556035
# Тестовые samples: 8863
# Обучение MultiOutput XGBoost...
# CAP - MSE: 2.7944, MAE: 0.5031, MAPE: 0.1232, R²: 0.9063
# LENGTH - MSE: 285.3777, MAE: 3.3006, MAPE: 0.1574, R²: 0.8499
# SEGS - MSE: 36.3764, MAE: 3.6473, MAPE: 0.3502, R²: 0.9497
#
# --- Фолд 4 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top'
#  'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['pcm_slv_top' 'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter']
# Тренировочные samples: 541474
# Тестовые samples: 23424
# Обучение MultiOutput XGBoost...
# CAP - MSE: 0.7515, MAE: 0.3101, MAPE: 0.1203, R²: 0.9613
# LENGTH - MSE: 34.8749, MAE: 1.7229, MAPE: 0.1453, R²: 0.9752
# SEGS - MSE: 21.7100, MAE: 2.8312, MAPE: 0.3268, R²: 0.9557
#
# --- Фолд 5 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'RocketTile' 'sdram'
#  'aes_core' 'picosoc' 'Network' 'fpu' 'dft_top' 'Top_PipelinedCipher'
#  'vga_enh_top' 'des3']
# Тестовые блоки (5): ['plic_core' 'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap'
#  'wb_dma_top']
# Тренировочные samples: 547156
# Тестовые samples: 17742
# Обучение MultiOutput XGBoost...
# CAP - MSE: 0.8394, MAE: 0.4154, MAPE: 0.0945, R²: 0.9731
# LENGTH - MSE: 24.9419, MAE: 2.0377, MAPE: 0.1109, R²: 0.9858
# SEGS - MSE: 34.6081, MAE: 3.6438, MAPE: 0.3282, R²: 0.9513
#
# --- Фолд 6 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top' 'fpu'
#  'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тестовые блоки (5): ['RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network']
# Тренировочные samples: 314309
# Тестовые samples: 250589
# Обучение MultiOutput XGBoost...
# CAP - MSE: 15.6579, MAE: 0.8376, MAPE: 0.0790, R²: 0.8661
# LENGTH - MSE: 1550.2679, MAE: 6.6829, MAPE: 0.1253, R²: 0.8015
# SEGS - MSE: 44.5046, MAE: 3.6576, MAPE: 0.3262, R²: 0.9560
#
# --- Фолд 7 ---
# Тренировочные блоки (30): ['mips_core' 'spi_top' 'RsDecodeTop' 'RsEncodeTop' 'risc16f84_clk2x'
#  'mc_top' 'Sha3BlackBox' 'pci_bridge32' 'wb_conmax_top' 'aes128_core'
#  'ac97_top' 'sha256' 'simple_spi_top' 'sasc_top' 'mrisc_top' 'pcm_slv_top'
#  'usb_phy' 'psram_core' 'jpeg_encoder' 'FIR_filter' 'plic_core'
#  'rs_encode' 'aes_cipher_top' 'dynamic_node_top_wrap' 'wb_dma_top'
#  'RocketTile' 'sdram' 'aes_core' 'picosoc' 'Network']
# Тестовые блоки (5): ['fpu' 'dft_top' 'Top_PipelinedCipher' 'vga_enh_top' 'des3']
# Тренировочные samples: 378760
# Тестовые samples: 186138
# Обучение MultiOutput XGBoost...
# CAP - MSE: 2.9909, MAE: 0.4743, MAPE: 0.0837, R²: 0.9388
# LENGTH - MSE: 153.3813, MAE: 2.7841, MAPE: 0.1181, R²: 0.9491
# SEGS - MSE: 182.2362, MAE: 4.1619, MAPE: 0.3286, R²: 0.8710
#
# ============================================================
# ИТОГИ КРОСС-ВАЛИДАЦИИ - МНОГОЗАДАЧНАЯ РЕГРЕССИЯ
# ============================================================
#
# 📊 CAP - Средние метрики по всем фолдам:
#   MSE:  5.9793 (±6.7087)
#   MAE:  0.5904 (±0.2751)
#   MAPE: 0.1062 (±0.0212)
#   R²:   0.9255 (±0.0418)
#
# 📊 LENGTH - Средние метрики по всем фолдам:
#   MSE:  371.4022 (±505.3076)
#   MAE:  3.3627 (±1.5748)
#   MAPE: 0.1344 (±0.0165)
#   R²:   0.9217 (±0.0657)
#
# 📊 SEGS - Средние метрики по всем фолдам:
#   MSE:  71.4445 (±59.2140)
#   MAE:  3.8186 (±0.6897)
#   MAPE: 0.3314 (±0.0086)
#   R²:   0.9335 (±0.0355)
#
# ==================================================
# АЛЬТЕРНАТИВА: ОТДЕЛЬНЫЕ МОДЕЛИ ДЛЯ КАЖДОГО ТАРГЕТА
# ==================================================
#
# --- Фолд 1 (Отдельные модели) ---
# Обучение XGBoost для cap...
#   CAP - MSE: 1.5050, R²: 0.9634
# Обучение XGBoost для length...
#   LENGTH - MSE: 62.1701, R²: 0.9751
# Обучение XGBoost для segs...
#   SEGS - MSE: 36.6286, R²: 0.9654
#
# --- Фолд 2 (Отдельные модели) ---
# Обучение XGBoost для cap...
#   CAP - MSE: 17.3163, R²: 0.8693
# Обучение XGBoost для length...
#   LENGTH - MSE: 488.8016, R²: 0.9153
# Обучение XGBoost для segs...
#   SEGS - MSE: 144.0474, R²: 0.8855
#
# --- Фолд 3 (Отдельные модели) ---
# Обучение XGBoost для cap...
#   CAP - MSE: 2.7944, R²: 0.9063
# Обучение XGBoost для length...
#   LENGTH - MSE: 285.3777, R²: 0.8499
# Обучение XGBoost для segs...
#   SEGS - MSE: 36.3764, R²: 0.9497
#
# --- Фолд 4 (Отдельные модели) ---
# Обучение XGBoost для cap...
#   CAP - MSE: 0.7515, R²: 0.9613
# Обучение XGBoost для length...
#   LENGTH - MSE: 34.8749, R²: 0.9752
# Обучение XGBoost для segs...
#   SEGS - MSE: 21.7100, R²: 0.9557
#
# --- Фолд 5 (Отдельные модели) ---
# Обучение XGBoost для cap...
#   CAP - MSE: 0.8394, R²: 0.9731
# Обучение XGBoost для length...
#   LENGTH - MSE: 24.9419, R²: 0.9858
# Обучение XGBoost для segs...
#   SEGS - MSE: 34.6081, R²: 0.9513
#
# --- Фолд 6 (Отдельные модели) ---
# Обучение XGBoost для cap...
#   CAP - MSE: 15.6579, R²: 0.8661
# Обучение XGBoost для length...
#   LENGTH - MSE: 1550.2679, R²: 0.8015
# Обучение XGBoost для segs...
#   SEGS - MSE: 44.5046, R²: 0.9560
#
# --- Фолд 7 (Отдельные модели) ---
# Обучение XGBoost для cap...
#   CAP - MSE: 2.9909, R²: 0.9388
# Обучение XGBoost для length...
#   LENGTH - MSE: 153.3813, R²: 0.9491
# Обучение XGBoost для segs...
#   SEGS - MSE: 182.2362, R²: 0.8710
#
# ============================================================
# СРАВНЕНИЕ ПОДХОДОВ
# ============================================================
#
# 🎯 CAP:
#   MultiOutput R²: 0.9255
#   Individual R²:  0.9255
#
# 🎯 LENGTH:
#   MultiOutput R²: 0.9217
#   Individual R²:  0.9217
#
# 🎯 SEGS:
#   MultiOutput R²: 0.9335
#   Individual R²:  0.9335
#
# Обучение финальных моделей на всех данных...
# ✅ Финальная MultiOutput модель обучена!
# ✅ Финальная модель для cap обучена!
# ✅ Финальная модель для length обучена!
# ✅ Финальная модель для segs обучена!
#
# 🎯 Все модели успешно обучены!
